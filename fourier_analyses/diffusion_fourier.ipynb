# %% [markdown]
# ### Preliminaries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tqdm
import torch
from torch import nn 
import torch.nn.functional as F
from torch import optim
from torch.autograd import grad

from argparse import Namespace
from functools import reduce
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/229 Project'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/229 Project

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### DeepXDE Setup

# %%
# install DeepXDE
# %pip install deepxde
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepxde
#   Downloading DeepXDE-1.8.4-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.10.1)
# Collecting scikit-optimize>=0.9.0
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from deepxde) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.2.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.2.0)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->deepxde) (3.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->deepxde) (3.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)
# Installing collected packages: pyaml, scikit-optimize, deepxde
# Successfully installed deepxde-1.8.4 pyaml-21.10.1 scikit-optimize-0.9.0

# %%
# import packages

from deepxde.backend.set_default_backend import set_default_backend
set_default_backend("tensorflow.compat.v1")

import deepxde as dde
import numpy as np

from deepxde.backend import tf

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
import random
# Out:
# No backend selected.
# Finding available backend...
# Using backend: tensorflow.compat.v1
# Other supported backends: tensorflow, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Found tensorflow.compat.v1
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)
# Enable just-in-time compilation with XLA.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)

# %%
# set up the problem
def pde(x, y):
    dy_t = dde.grad.jacobian(y, x, j=1)
    dy_xx = dde.grad.hessian(y, x, j=0)
    return (
        dy_t
        - dy_xx
        + tf.exp(-x[:, 1:])
        * (tf.sin(np.pi * x[:, 0:1]) - np.pi ** 2 * tf.sin(np.pi * x[:, 0:1]))
    )

def func(x):
    return np.sin(np.pi * x[:, 0:1]) * np.exp(-x[:, 1:])


geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0.5, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

bc = dde.icbc.DirichletBC(geomtime, func, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(geomtime, func, lambda _, on_initial: on_initial)
data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc, ic],
    num_domain=40,
    num_boundary=20,
    num_initial=10,
    solution=func,
    num_test=10000,
)

# %%
# set up the model
layer_size = [2] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

model = dde.Model(data, net)

model.compile("adam", lr=0.001, metrics=["l2 relative error"])
# Out:
# Compiling model...
# Building feed-forward neural network...
# /usr/local/lib/python3.9/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:114: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'build' took 0.227078 s
#
# 'compile' took 10.883007 s

# %%
def gen_testdata():
  full_domain = np.zeros(shape=(25600, 2))
  true_sol = np.zeros(shape=(25600,))
  for time_step in range(100):
    time = time_step * .01
    x = geom.uniform_points(256, True)
    t = np.full(256, time)
    x = np.hstack((x, t.reshape(-1, 1)))

    start = int(256 * time * 100)
    end = start + 256
    full_domain[start:end] = x

    ground_truth = np.exp(-time) * np.sin(np.pi * x[:, 0])
    true_sol[start:end] = ground_truth
  
  return full_domain, true_sol

# %% [markdown]
# ### Train Model

# %%
# import pickle

# # train the model
# model_preds = {}

# for iter in range(100):
#   losshistory, train_state = model.train(iterations=500)
#   X, y_true = gen_testdata()
#   y_pred = model.predict(X)
#   cur_iter = (iter + 1) * 500
#   model_preds[cur_iter] = y_pred

# with open('model_preds_diffusion.pkl', 'wb') as f:
#   pickle.dump(model_preds, f)
# Out:
# Training model...
#
# 0         [7.50e+00, 2.76e-01, 1.38e-01]    [9.27e+00, 2.76e-01, 1.38e-01]    [1.37e+00]
# 500       [3.15e-03, 3.98e-03, 1.00e-03]    [4.12e-03, 3.98e-03, 1.00e-03]    [1.13e-01]
#
# Best model at step 500:
#   train loss: 8.13e-03
#   test loss: 9.11e-03
#   test metric: [1.13e-01]
#
# 'train' took 5.624886 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 500       [3.15e-03, 3.98e-03, 1.00e-03]    [4.12e-03, 3.98e-03, 1.00e-03]    [1.13e-01]
# 1000      [1.18e-03, 1.38e-03, 2.03e-04]    [1.59e-03, 1.38e-03, 2.03e-04]    [6.61e-02]
#
# Best model at step 1000:
#   train loss: 2.76e-03
#   test loss: 3.18e-03
#   test metric: [6.61e-02]
#
# 'train' took 1.325740 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 1000      [1.18e-03, 1.38e-03, 2.03e-04]    [1.59e-03, 1.38e-03, 2.03e-04]    [6.61e-02]
# 1500      [1.16e-03, 5.88e-04, 1.34e-04]    [1.30e-03, 5.88e-04, 1.34e-04]    [4.63e-02]
#
# Best model at step 1500:
#   train loss: 1.88e-03
#   test loss: 2.02e-03
#   test metric: [4.63e-02]
#
# 'train' took 1.347605 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 1500      [1.16e-03, 5.88e-04, 1.34e-04]    [1.30e-03, 5.88e-04, 1.34e-04]    [4.63e-02]
# 2000      [4.18e-04, 3.03e-04, 1.07e-04]    [6.40e-04, 3.03e-04, 1.07e-04]    [3.28e-02]
#
# Best model at step 2000:
#   train loss: 8.28e-04
#   test loss: 1.05e-03
#   test metric: [3.28e-02]
#
# 'train' took 1.428177 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 2000      [4.18e-04, 3.03e-04, 1.07e-04]    [6.40e-04, 3.03e-04, 1.07e-04]    [3.28e-02]
# 2500      [2.65e-04, 2.19e-04, 9.49e-05]    [4.17e-04, 2.19e-04, 9.49e-05]    [2.83e-02]
#
# Best model at step 2500:
#   train loss: 5.79e-04
#   test loss: 7.30e-04
#   test metric: [2.83e-02]
#
# 'train' took 1.625962 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 2500      [2.65e-04, 2.19e-04, 9.49e-05]    [4.17e-04, 2.19e-04, 9.49e-05]    [2.83e-02]
# 3000      [2.25e-04, 1.61e-04, 9.60e-05]    [3.73e-04, 1.61e-04, 9.60e-05]    [2.56e-02]
#
# Best model at step 3000:
#   train loss: 4.83e-04
#   test loss: 6.30e-04
#   test metric: [2.56e-02]
#
# 'train' took 1.483720 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 3000      [2.25e-04, 1.61e-04, 9.60e-05]    [3.73e-04, 1.61e-04, 9.60e-05]    [2.56e-02]
# 3500      [1.32e-04, 1.30e-04, 7.23e-05]    [2.37e-04, 1.30e-04, 7.23e-05]    [2.25e-02]
#
# Best model at step 3500:
#   train loss: 3.34e-04
#   test loss: 4.39e-04
#   test metric: [2.25e-02]
#
# 'train' took 2.848188 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 3500      [1.32e-04, 1.30e-04, 7.23e-05]    [2.37e-04, 1.30e-04, 7.23e-05]    [2.25e-02]
# 4000      [1.09e-03, 1.13e-04, 6.33e-05]    [9.60e-04, 1.13e-04, 6.33e-05]    [2.27e-02]
#
# Best model at step 3500:
#   train loss: 3.34e-04
#   test loss: 4.39e-04
#   test metric: [2.25e-02]
#
# 'train' took 1.939965 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 4000      [1.09e-03, 1.13e-04, 6.33e-05]    [9.60e-04, 1.13e-04, 6.33e-05]    [2.27e-02]
# 4500      [9.35e-05, 8.66e-05, 5.10e-05]    [1.87e-04, 8.66e-05, 5.10e-05]    [1.84e-02]
#
# Best model at step 4500:
#   train loss: 2.31e-04
#   test loss: 3.24e-04
#   test metric: [1.84e-02]
#
# 'train' took 1.197445 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 4500      [9.35e-05, 8.66e-05, 5.10e-05]    [1.87e-04, 8.66e-05, 5.10e-05]    [1.84e-02]
# 5000      [1.07e-03, 1.04e-04, 8.79e-05]    [1.19e-03, 1.04e-04, 8.79e-05]    [2.27e-02]
#
# Best model at step 4500:
#   train loss: 2.31e-04
#   test loss: 3.24e-04
#   test metric: [1.84e-02]
#
# 'train' took 1.365483 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 5000      [1.07e-03, 1.04e-04, 8.79e-05]    [1.19e-03, 1.04e-04, 8.79e-05]    [2.27e-02]
# 5500      [2.96e-04, 9.16e-05, 3.50e-05]    [3.18e-04, 9.16e-05, 3.50e-05]    [1.74e-02]
#
# Best model at step 4500:
#   train loss: 2.31e-04
#   test loss: 3.24e-04
#   test metric: [1.84e-02]
#
# 'train' took 1.715650 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 5500      [2.96e-04, 9.16e-05, 3.50e-05]    [3.18e-04, 9.16e-05, 3.50e-05]    [1.74e-02]
# 6000      [4.23e-04, 1.20e-04, 3.02e-05]    [2.46e-04, 1.20e-04, 3.02e-05]    [1.82e-02]
#
# Best model at step 4500:
#   train loss: 2.31e-04
#   test loss: 3.24e-04
#   test metric: [1.84e-02]
#
# 'train' took 0.841622 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 6000      [4.23e-04, 1.20e-04, 3.02e-05]    [2.46e-04, 1.20e-04, 3.02e-05]    [1.82e-02]
# 6500      [2.13e-04, 5.37e-05, 3.70e-05]    [2.72e-04, 5.37e-05, 3.70e-05]    [1.58e-02]
#
# Best model at step 4500:
#   train loss: 2.31e-04
#   test loss: 3.24e-04
#   test metric: [1.84e-02]
#
# 'train' took 0.783481 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 6500      [2.13e-04, 5.37e-05, 3.70e-05]    [2.72e-04, 5.37e-05, 3.70e-05]    [1.58e-02]
# 7000      [4.71e-05, 3.51e-05, 2.51e-05]    [1.35e-04, 3.51e-05, 2.51e-05]    [1.17e-02]
#
# Best model at step 7000:
#   train loss: 1.07e-04
#   test loss: 1.95e-04
#   test metric: [1.17e-02]
#
# 'train' took 0.798696 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 7000      [4.71e-05, 3.51e-05, 2.51e-05]    [1.35e-04, 3.51e-05, 2.51e-05]    [1.17e-02]
# 7500      [6.53e-05, 2.88e-05, 2.36e-05]    [1.53e-04, 2.88e-05, 2.36e-05]    [1.07e-02]
#
# Best model at step 7000:
#   train loss: 1.07e-04
#   test loss: 1.95e-04
#   test metric: [1.17e-02]
#
# 'train' took 0.780706 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 7500      [6.53e-05, 2.88e-05, 2.36e-05]    [1.53e-04, 2.88e-05, 2.36e-05]    [1.07e-02]
# 8000      [6.22e-05, 2.35e-05, 2.07e-05]    [1.51e-04, 2.35e-05, 2.07e-05]    [1.00e-02]
#
# Best model at step 8000:
#   train loss: 1.06e-04
#   test loss: 1.96e-04
#   test metric: [1.00e-02]
#
# 'train' took 0.793311 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 8000      [6.22e-05, 2.35e-05, 2.07e-05]    [1.51e-04, 2.35e-05, 2.07e-05]    [1.00e-02]
# 8500      [7.48e-05, 2.34e-05, 1.05e-05]    [1.20e-04, 2.34e-05, 1.05e-05]    [9.04e-03]
#
# Best model at step 8000:
#   train loss: 1.06e-04
#   test loss: 1.96e-04
#   test metric: [1.00e-02]
#
# 'train' took 0.869439 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 8500      [7.48e-05, 2.34e-05, 1.05e-05]    [1.20e-04, 2.34e-05, 1.05e-05]    [9.04e-03]
# 9000      [3.24e-05, 1.62e-05, 1.04e-05]    [9.74e-05, 1.62e-05, 1.04e-05]    [7.60e-03]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 1.042949 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 9000      [3.24e-05, 1.62e-05, 1.04e-05]    [9.74e-05, 1.62e-05, 1.04e-05]    [7.60e-03]
# 9500      [7.38e-04, 5.41e-05, 3.51e-05]    [7.51e-04, 5.41e-05, 3.51e-05]    [1.41e-02]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 1.011360 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 9500      [7.38e-04, 5.41e-05, 3.51e-05]    [7.51e-04, 5.41e-05, 3.51e-05]    [1.41e-02]
# 10000     [1.45e-04, 1.49e-05, 1.71e-05]    [2.03e-04, 1.49e-05, 1.71e-05]    [9.86e-03]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 1.010606 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 10000     [1.45e-04, 1.49e-05, 1.71e-05]    [2.03e-04, 1.49e-05, 1.71e-05]    [9.86e-03]
# 10500     [1.19e-03, 7.52e-05, 4.38e-05]    [1.15e-03, 7.52e-05, 4.38e-05]    [1.75e-02]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 0.849511 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 10500     [1.19e-03, 7.52e-05, 4.38e-05]    [1.15e-03, 7.52e-05, 4.38e-05]    [1.75e-02]
# 11000     [2.19e-03, 1.53e-04, 5.09e-05]    [1.98e-03, 1.53e-04, 5.09e-05]    [2.07e-02]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 0.791856 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 11000     [2.19e-03, 1.53e-04, 5.09e-05]    [1.98e-03, 1.53e-04, 5.09e-05]    [2.07e-02]
# 11500     [2.93e-03, 4.93e-04, 1.26e-04]    [1.42e-03, 4.93e-04, 1.26e-04]    [3.85e-02]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 0.800517 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 11500     [2.93e-03, 4.93e-04, 1.26e-04]    [1.42e-03, 4.93e-04, 1.26e-04]    [3.85e-02]
# 12000     [3.17e-04, 6.92e-05, 3.23e-05]    [3.92e-04, 6.92e-05, 3.23e-05]    [1.70e-02]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 0.809609 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 12000     [3.17e-04, 6.92e-05, 3.23e-05]    [3.92e-04, 6.92e-05, 3.23e-05]    [1.70e-02]
# 12500     [6.97e-04, 9.03e-05, 8.28e-06]    [4.19e-04, 9.03e-05, 8.28e-06]    [1.43e-02]
#
# Best model at step 9000:
#   train loss: 5.90e-05
#   test loss: 1.24e-04
#   test metric: [7.60e-03]
#
# 'train' took 0.795940 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 12500     [6.97e-04, 9.03e-05, 8.28e-06]    [4.19e-04, 9.03e-05, 8.28e-06]    [1.43e-02]
# 13000     [1.78e-05, 2.27e-06, 2.05e-06]    [7.50e-05, 2.27e-06, 2.05e-06]    [2.90e-03]
#
# Best model at step 13000:
#   train loss: 2.21e-05
#   test loss: 7.94e-05
#   test metric: [2.90e-03]
#
# 'train' took 0.821657 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 13000     [1.78e-05, 2.27e-06, 2.05e-06]    [7.50e-05, 2.27e-06, 2.05e-06]    [2.90e-03]
# 13500     [6.72e-04, 2.64e-05, 1.54e-05]    [5.56e-04, 2.64e-05, 1.54e-05]    [8.75e-03]
#
# Best model at step 13000:
#   train loss: 2.21e-05
#   test loss: 7.94e-05
#   test metric: [2.90e-03]
#
# 'train' took 0.792885 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 13500     [6.72e-04, 2.64e-05, 1.54e-05]    [5.56e-04, 2.64e-05, 1.54e-05]    [8.75e-03]
# 14000     [1.47e-04, 2.02e-05, 1.56e-05]    [2.70e-04, 2.02e-05, 1.56e-05]    [1.12e-02]
#
# Best model at step 13000:
#   train loss: 2.21e-05
#   test loss: 7.94e-05
#   test metric: [2.90e-03]
#
# 'train' took 0.801362 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 14000     [1.47e-04, 2.02e-05, 1.56e-05]    [2.70e-04, 2.02e-05, 1.56e-05]    [1.12e-02]
# 14500     [2.05e-05, 1.62e-06, 2.61e-06]    [8.55e-05, 1.62e-06, 2.61e-06]    [3.17e-03]
#
# Best model at step 13000:
#   train loss: 2.21e-05
#   test loss: 7.94e-05
#   test metric: [2.90e-03]
#
# 'train' took 0.784454 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 14500     [2.05e-05, 1.62e-06, 2.61e-06]    [8.55e-05, 1.62e-06, 2.61e-06]    [3.17e-03]
# 15000     [2.92e-05, 2.48e-06, 1.01e-06]    [6.29e-05, 2.48e-06, 1.01e-06]    [2.47e-03]
#
# Best model at step 13000:
#   train loss: 2.21e-05
#   test loss: 7.94e-05
#   test metric: [2.90e-03]
#
# 'train' took 0.783692 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 15000     [2.92e-05, 2.48e-06, 1.01e-06]    [6.29e-05, 2.48e-06, 1.01e-06]    [2.47e-03]
# 15500     [1.31e-05, 1.51e-06, 1.37e-06]    [5.81e-05, 1.51e-06, 1.37e-06]    [2.19e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 0.789587 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 15500     [1.31e-05, 1.51e-06, 1.37e-06]    [5.81e-05, 1.51e-06, 1.37e-06]    [2.19e-03]
# 16000     [2.33e-05, 2.23e-06, 1.06e-06]    [7.32e-05, 2.23e-06, 1.06e-06]    [2.62e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 0.804144 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 16000     [2.33e-05, 2.23e-06, 1.06e-06]    [7.32e-05, 2.23e-06, 1.06e-06]    [2.62e-03]
# 16500     [6.51e-05, 1.71e-06, 1.49e-06]    [1.21e-04, 1.71e-06, 1.49e-06]    [2.55e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 0.881566 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 16500     [6.51e-05, 1.71e-06, 1.49e-06]    [1.21e-04, 1.71e-06, 1.49e-06]    [2.55e-03]
# 17000     [3.37e-05, 1.92e-06, 2.99e-06]    [8.05e-05, 1.92e-06, 2.99e-06]    [4.41e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 1.009912 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 17000     [3.37e-05, 1.92e-06, 2.99e-06]    [8.05e-05, 1.92e-06, 2.99e-06]    [4.41e-03]
# 17500     [2.00e-05, 1.23e-06, 1.08e-06]    [5.32e-05, 1.23e-06, 1.08e-06]    [2.34e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 1.021284 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 17500     [2.00e-05, 1.23e-06, 1.08e-06]    [5.32e-05, 1.23e-06, 1.08e-06]    [2.34e-03]
# 18000     [1.46e-05, 1.17e-06, 9.80e-07]    [5.18e-05, 1.17e-06, 9.80e-07]    [1.77e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 1.046617 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 18000     [1.46e-05, 1.17e-06, 9.80e-07]    [5.18e-05, 1.17e-06, 9.80e-07]    [1.77e-03]
# 18500     [1.95e-03, 3.37e-05, 3.50e-05]    [2.03e-03, 3.37e-05, 3.50e-05]    [1.75e-02]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 0.812866 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 18500     [1.95e-03, 3.37e-05, 3.50e-05]    [2.03e-03, 3.37e-05, 3.50e-05]    [1.75e-02]
# 19000     [8.02e-05, 1.07e-05, 1.36e-06]    [7.33e-05, 1.07e-05, 1.36e-06]    [5.19e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 0.794655 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 19000     [8.02e-05, 1.07e-05, 1.36e-06]    [7.33e-05, 1.07e-05, 1.36e-06]    [5.19e-03]
# 19500     [2.84e-04, 9.86e-06, 1.08e-05]    [4.14e-04, 9.86e-06, 1.08e-05]    [9.90e-03]
#
# Best model at step 15500:
#   train loss: 1.60e-05
#   test loss: 6.10e-05
#   test metric: [2.19e-03]
#
# 'train' took 0.795638 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 19500     [2.84e-04, 9.86e-06, 1.08e-05]    [4.14e-04, 9.86e-06, 1.08e-05]    [9.90e-03]
# 20000     [9.80e-06, 1.00e-06, 6.83e-07]    [4.93e-05, 1.00e-06, 6.82e-07]    [1.42e-03]
#
# Best model at step 20000:
#   train loss: 1.15e-05
#   test loss: 5.10e-05
#   test metric: [1.42e-03]
#
# 'train' took 0.818676 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 20000     [9.80e-06, 1.00e-06, 6.83e-07]    [4.93e-05, 1.00e-06, 6.82e-07]    [1.42e-03]
# 20500     [2.37e-04, 9.67e-06, 4.48e-06]    [1.53e-04, 9.67e-06, 4.48e-06]    [6.27e-03]
#
# Best model at step 20000:
#   train loss: 1.15e-05
#   test loss: 5.10e-05
#   test metric: [1.42e-03]
#
# 'train' took 0.808648 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 20500     [2.37e-04, 9.67e-06, 4.48e-06]    [1.53e-04, 9.67e-06, 4.48e-06]    [6.27e-03]
# 21000     [9.70e-05, 7.51e-06, 1.05e-05]    [7.92e-05, 7.51e-06, 1.05e-05]    [9.44e-03]
#
# Best model at step 20000:
#   train loss: 1.15e-05
#   test loss: 5.10e-05
#   test metric: [1.42e-03]
#
# 'train' took 0.789875 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 21000     [9.70e-05, 7.51e-06, 1.05e-05]    [7.92e-05, 7.51e-06, 1.05e-05]    [9.44e-03]
# 21500     [2.54e-05, 6.55e-06, 9.25e-06]    [6.23e-05, 6.55e-06, 9.25e-06]    [9.26e-03]
#
# Best model at step 20000:
#   train loss: 1.15e-05
#   test loss: 5.10e-05
#   test metric: [1.42e-03]
#
# 'train' took 0.785830 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 21500     [2.54e-05, 6.55e-06, 9.25e-06]    [6.23e-05, 6.55e-06, 9.25e-06]    [9.26e-03]
# 22000     [2.81e-04, 1.00e-05, 2.12e-06]    [1.87e-04, 1.00e-05, 2.12e-06]    [4.01e-03]
#
# Best model at step 20000:
#   train loss: 1.15e-05
#   test loss: 5.10e-05
#   test metric: [1.42e-03]
#
# 'train' took 0.803340 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 22000     [2.81e-04, 1.00e-05, 2.12e-06]    [1.87e-04, 1.00e-05, 2.12e-06]    [4.01e-03]
# 22500     [1.38e-05, 1.24e-06, 5.34e-07]    [5.00e-05, 1.24e-06, 5.34e-07]    [1.70e-03]
#
# Best model at step 20000:
#   train loss: 1.15e-05
#   test loss: 5.10e-05
#   test metric: [1.42e-03]
#
# 'train' took 0.810145 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 22500     [1.38e-05, 1.24e-06, 5.34e-07]    [5.00e-05, 1.24e-06, 5.34e-07]    [1.70e-03]
# 23000     [9.44e-05, 7.99e-06, 3.49e-06]    [9.51e-05, 7.99e-06, 3.49e-06]    [6.28e-03]
#
# Best model at step 20000:
#   train loss: 1.15e-05
#   test loss: 5.10e-05
#   test metric: [1.42e-03]
#
# 'train' took 0.782586 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 23000     [9.44e-05, 7.99e-06, 3.49e-06]    [9.51e-05, 7.99e-06, 3.49e-06]    [6.28e-03]
# 23500     [9.18e-06, 1.12e-06, 7.72e-07]    [3.84e-05, 1.12e-06, 7.72e-07]    [1.43e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.781692 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 23500     [9.18e-06, 1.12e-06, 7.72e-07]    [3.84e-05, 1.12e-06, 7.72e-07]    [1.43e-03]
# 24000     [1.15e-05, 1.11e-06, 5.41e-07]    [4.50e-05, 1.11e-06, 5.41e-07]    [1.54e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.800376 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 24000     [1.15e-05, 1.11e-06, 5.41e-07]    [4.50e-05, 1.11e-06, 5.41e-07]    [1.54e-03]
# 24500     [2.76e-05, 1.47e-05, 1.43e-05]    [5.70e-05, 1.47e-05, 1.43e-05]    [1.26e-02]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.944095 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 24500     [2.76e-05, 1.47e-05, 1.43e-05]    [5.70e-05, 1.47e-05, 1.43e-05]    [1.26e-02]
# 25000     [3.22e-05, 2.62e-06, 1.91e-06]    [7.14e-05, 2.62e-06, 1.91e-06]    [3.31e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.981463 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 25000     [3.22e-05, 2.62e-06, 1.91e-06]    [7.14e-05, 2.62e-06, 1.91e-06]    [3.31e-03]
# 25500     [1.08e-05, 1.75e-06, 8.12e-07]    [3.26e-05, 1.75e-06, 8.11e-07]    [1.84e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.980506 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 25500     [1.08e-05, 1.75e-06, 8.12e-07]    [3.26e-05, 1.75e-06, 8.11e-07]    [1.84e-03]
# 26000     [1.56e-05, 1.27e-06, 1.10e-06]    [4.96e-05, 1.27e-06, 1.10e-06]    [1.85e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.983398 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 26000     [1.56e-05, 1.27e-06, 1.10e-06]    [4.96e-05, 1.27e-06, 1.10e-06]    [1.85e-03]
# 26500     [8.59e-04, 8.34e-05, 4.48e-05]    [1.16e-03, 8.34e-05, 4.48e-05]    [2.28e-02]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.783965 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 26500     [8.59e-04, 8.34e-05, 4.48e-05]    [1.16e-03, 8.34e-05, 4.48e-05]    [2.28e-02]
# 27000     [4.20e-05, 5.06e-06, 3.41e-06]    [5.90e-05, 5.06e-06, 3.42e-06]    [6.00e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.776044 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 27000     [4.20e-05, 5.06e-06, 3.41e-06]    [5.90e-05, 5.06e-06, 3.42e-06]    [6.00e-03]
# 27500     [4.48e-05, 1.76e-06, 3.10e-06]    [7.47e-05, 1.76e-06, 3.10e-06]    [4.42e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.799814 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 27500     [4.48e-05, 1.76e-06, 3.10e-06]    [7.47e-05, 1.76e-06, 3.10e-06]    [4.42e-03]
# 28000     [1.06e-05, 1.03e-06, 5.82e-07]    [3.61e-05, 1.03e-06, 5.82e-07]    [1.29e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.793346 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 28000     [1.06e-05, 1.03e-06, 5.82e-07]    [3.61e-05, 1.03e-06, 5.82e-07]    [1.29e-03]
# 28500     [1.09e-04, 1.67e-05, 2.57e-06]    [5.25e-05, 1.67e-05, 2.57e-06]    [6.13e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.797972 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 28500     [1.09e-04, 1.67e-05, 2.57e-06]    [5.25e-05, 1.67e-05, 2.57e-06]    [6.13e-03]
# 29000     [1.54e-05, 2.42e-06, 3.10e-06]    [4.07e-05, 2.42e-06, 3.10e-06]    [4.67e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.788234 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 29000     [1.54e-05, 2.42e-06, 3.10e-06]    [4.07e-05, 2.42e-06, 3.10e-06]    [4.67e-03]
# 29500     [1.16e-04, 1.65e-05, 5.50e-06]    [1.14e-04, 1.65e-05, 5.50e-06]    [7.41e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.786750 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 29500     [1.16e-04, 1.65e-05, 5.50e-06]    [1.14e-04, 1.65e-05, 5.50e-06]    [7.41e-03]
# 30000     [2.27e-05, 1.12e-06, 1.26e-06]    [3.49e-05, 1.12e-06, 1.26e-06]    [2.26e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.802859 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 30000     [2.27e-05, 1.12e-06, 1.26e-06]    [3.49e-05, 1.12e-06, 1.26e-06]    [2.26e-03]
# 30500     [1.12e-05, 1.17e-06, 1.38e-06]    [4.01e-05, 1.17e-06, 1.38e-06]    [2.93e-03]
#
# Best model at step 23500:
#   train loss: 1.11e-05
#   test loss: 4.02e-05
#   test metric: [1.43e-03]
#
# 'train' took 0.776207 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 30500     [1.12e-05, 1.17e-06, 1.38e-06]    [4.01e-05, 1.17e-06, 1.38e-06]    [2.93e-03]
# 31000     [7.58e-06, 1.22e-06, 1.27e-06]    [3.53e-05, 1.22e-06, 1.27e-06]    [2.60e-03]
#
# Best model at step 31000:
#   train loss: 1.01e-05
#   test loss: 3.78e-05
#   test metric: [2.60e-03]
#
# 'train' took 0.791141 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 31000     [7.58e-06, 1.22e-06, 1.27e-06]    [3.53e-05, 1.22e-06, 1.27e-06]    [2.60e-03]
# 31500     [6.05e-06, 9.79e-07, 8.12e-07]    [3.02e-05, 9.79e-07, 8.13e-07]    [1.39e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 0.818735 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 31500     [6.05e-06, 9.79e-07, 8.12e-07]    [3.02e-05, 9.79e-07, 8.13e-07]    [1.39e-03]
# 32000     [1.20e-03, 4.11e-05, 1.37e-05]    [6.69e-04, 4.11e-05, 1.37e-05]    [9.17e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 0.784258 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 32000     [1.20e-03, 4.11e-05, 1.37e-05]    [6.69e-04, 4.11e-05, 1.37e-05]    [9.17e-03]
# 32500     [1.39e-05, 1.20e-06, 1.56e-06]    [4.13e-05, 1.20e-06, 1.56e-06]    [2.92e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 1.000523 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 32500     [1.39e-05, 1.20e-06, 1.56e-06]    [4.13e-05, 1.20e-06, 1.56e-06]    [2.92e-03]
# 33000     [6.41e-06, 9.44e-07, 8.43e-07]    [2.93e-05, 9.44e-07, 8.43e-07]    [1.44e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 1.026088 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 33000     [6.41e-06, 9.44e-07, 8.43e-07]    [2.93e-05, 9.44e-07, 8.43e-07]    [1.44e-03]
# 33500     [2.39e-04, 4.32e-05, 1.31e-05]    [1.84e-04, 4.32e-05, 1.31e-05]    [1.27e-02]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 1.014294 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 33500     [2.39e-04, 4.32e-05, 1.31e-05]    [1.84e-04, 4.32e-05, 1.31e-05]    [1.27e-02]
# 34000     [5.59e-05, 2.25e-06, 3.05e-06]    [9.42e-05, 2.25e-06, 3.05e-06]    [4.26e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 0.957572 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 34000     [5.59e-05, 2.25e-06, 3.05e-06]    [9.42e-05, 2.25e-06, 3.05e-06]    [4.26e-03]
# 34500     [2.21e-05, 1.94e-06, 3.46e-06]    [4.89e-05, 1.94e-06, 3.46e-06]    [5.23e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 0.792488 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 34500     [2.21e-05, 1.94e-06, 3.46e-06]    [4.89e-05, 1.94e-06, 3.46e-06]    [5.23e-03]
# 35000     [7.93e-06, 9.02e-07, 5.45e-07]    [3.32e-05, 9.02e-07, 5.45e-07]    [1.05e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 0.827627 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 35000     [7.93e-06, 9.02e-07, 5.45e-07]    [3.32e-05, 9.02e-07, 5.45e-07]    [1.05e-03]
# 35500     [4.07e-05, 5.11e-06, 4.34e-06]    [8.16e-05, 5.10e-06, 4.34e-06]    [5.78e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 0.816033 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 35500     [4.07e-05, 5.11e-06, 4.34e-06]    [8.16e-05, 5.10e-06, 4.34e-06]    [5.78e-03]
# 36000     [2.72e-05, 2.97e-06, 7.68e-07]    [2.75e-05, 2.97e-06, 7.68e-07]    [2.24e-03]
#
# Best model at step 31500:
#   train loss: 7.84e-06
#   test loss: 3.20e-05
#   test metric: [1.39e-03]
#
# 'train' took 0.806618 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 36000     [2.72e-05, 2.97e-06, 7.68e-07]    [2.75e-05, 2.97e-06, 7.68e-07]    [2.24e-03]
# 36500     [5.57e-06, 9.29e-07, 7.01e-07]    [2.72e-05, 9.29e-07, 7.01e-07]    [1.13e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.807117 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 36500     [5.57e-06, 9.29e-07, 7.01e-07]    [2.72e-05, 9.29e-07, 7.01e-07]    [1.13e-03]
# 37000     [1.47e-04, 1.68e-05, 1.39e-05]    [9.90e-05, 1.68e-05, 1.39e-05]    [1.09e-02]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.796032 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 37000     [1.47e-04, 1.68e-05, 1.39e-05]    [9.90e-05, 1.68e-05, 1.39e-05]    [1.09e-02]
# 37500     [2.75e-04, 7.47e-06, 5.15e-06]    [2.53e-04, 7.46e-06, 5.15e-06]    [5.20e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.807177 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 37500     [2.75e-04, 7.47e-06, 5.15e-06]    [2.53e-04, 7.46e-06, 5.15e-06]    [5.20e-03]
# 38000     [7.47e-06, 1.55e-06, 6.40e-07]    [2.29e-05, 1.55e-06, 6.40e-07]    [1.72e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.797495 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 38000     [7.47e-06, 1.55e-06, 6.40e-07]    [2.29e-05, 1.55e-06, 6.40e-07]    [1.72e-03]
# 38500     [6.09e-04, 1.72e-05, 8.42e-06]    [5.32e-04, 1.72e-05, 8.42e-06]    [8.50e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.829992 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 38500     [6.09e-04, 1.72e-05, 8.42e-06]    [5.32e-04, 1.72e-05, 8.42e-06]    [8.50e-03]
# 39000     [6.10e-05, 1.34e-05, 2.14e-05]    [1.01e-04, 1.34e-05, 2.14e-05]    [1.51e-02]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.807163 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 39000     [6.10e-05, 1.34e-05, 2.14e-05]    [1.01e-04, 1.34e-05, 2.14e-05]    [1.51e-02]
# 39500     [6.34e-04, 1.44e-05, 8.67e-06]    [3.59e-04, 1.44e-05, 8.67e-06]    [8.22e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.785427 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 39500     [6.34e-04, 1.44e-05, 8.67e-06]    [3.59e-04, 1.44e-05, 8.67e-06]    [8.22e-03]
# 40000     [1.35e-05, 1.88e-06, 1.39e-06]    [4.02e-05, 1.88e-06, 1.39e-06]    [2.59e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.854240 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 40000     [1.35e-05, 1.88e-06, 1.39e-06]    [4.02e-05, 1.88e-06, 1.39e-06]    [2.59e-03]
# 40500     [1.15e-04, 1.17e-06, 2.82e-06]    [1.36e-04, 1.17e-06, 2.82e-06]    [3.91e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 1.003971 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 40500     [1.15e-04, 1.17e-06, 2.82e-06]    [1.36e-04, 1.17e-06, 2.82e-06]    [3.91e-03]
# 41000     [1.17e-05, 1.52e-06, 1.24e-06]    [3.95e-05, 1.52e-06, 1.24e-06]    [2.30e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 1.010467 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 41000     [1.17e-05, 1.52e-06, 1.24e-06]    [3.95e-05, 1.52e-06, 1.24e-06]    [2.30e-03]
# 41500     [1.43e-04, 9.20e-06, 2.97e-06]    [8.22e-05, 9.20e-06, 2.97e-06]    [4.38e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 1.019408 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 41500     [1.43e-04, 9.20e-06, 2.97e-06]    [8.22e-05, 9.20e-06, 2.97e-06]    [4.38e-03]
# 42000     [3.68e-05, 3.23e-06, 2.10e-06]    [2.72e-05, 3.23e-06, 2.10e-06]    [3.58e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.876673 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 42000     [3.68e-05, 3.23e-06, 2.10e-06]    [2.72e-05, 3.23e-06, 2.10e-06]    [3.58e-03]
# 42500     [5.95e-05, 4.61e-06, 4.81e-06]    [8.12e-05, 4.61e-06, 4.81e-06]    [6.59e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.788219 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 42500     [5.95e-05, 4.61e-06, 4.81e-06]    [8.12e-05, 4.61e-06, 4.81e-06]    [6.59e-03]
# 43000     [2.28e-05, 1.32e-06, 1.87e-06]    [4.33e-05, 1.32e-06, 1.87e-06]    [3.09e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.792213 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 43000     [2.28e-05, 1.32e-06, 1.87e-06]    [4.33e-05, 1.32e-06, 1.87e-06]    [3.09e-03]
# 43500     [1.73e-05, 1.13e-06, 8.64e-07]    [3.89e-05, 1.13e-06, 8.64e-07]    [1.56e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.791195 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 43500     [1.73e-05, 1.13e-06, 8.64e-07]    [3.89e-05, 1.13e-06, 8.64e-07]    [1.56e-03]
# 44000     [5.50e-04, 2.26e-05, 1.82e-05]    [4.62e-04, 2.26e-05, 1.82e-05]    [1.26e-02]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.800947 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 44000     [5.50e-04, 2.26e-05, 1.82e-05]    [4.62e-04, 2.26e-05, 1.82e-05]    [1.26e-02]
# 44500     [3.15e-05, 1.21e-06, 1.79e-06]    [5.47e-05, 1.21e-06, 1.79e-06]    [3.36e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.791488 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 44500     [3.15e-05, 1.21e-06, 1.79e-06]    [5.47e-05, 1.21e-06, 1.79e-06]    [3.36e-03]
# 45000     [1.74e-05, 3.41e-06, 1.78e-06]    [2.95e-05, 3.41e-06, 1.78e-06]    [4.09e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.787635 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 45000     [1.74e-05, 3.41e-06, 1.78e-06]    [2.95e-05, 3.41e-06, 1.78e-06]    [4.09e-03]
# 45500     [1.49e-04, 2.46e-05, 1.41e-05]    [1.82e-04, 2.46e-05, 1.41e-05]    [1.17e-02]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.786587 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 45500     [1.49e-04, 2.46e-05, 1.41e-05]    [1.82e-04, 2.46e-05, 1.41e-05]    [1.17e-02]
# 46000     [1.25e-05, 3.29e-06, 1.10e-06]    [2.02e-05, 3.29e-06, 1.10e-06]    [3.33e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.791594 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 46000     [1.25e-05, 3.29e-06, 1.10e-06]    [2.02e-05, 3.29e-06, 1.10e-06]    [3.33e-03]
# 46500     [2.38e-05, 2.34e-06, 3.94e-06]    [4.22e-05, 2.34e-06, 3.94e-06]    [5.61e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.775161 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 46500     [2.38e-05, 2.34e-06, 3.94e-06]    [4.22e-05, 2.34e-06, 3.94e-06]    [5.61e-03]
# 47000     [3.78e-04, 8.17e-06, 2.90e-06]    [3.61e-04, 8.17e-06, 2.90e-06]    [4.94e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.813678 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 47000     [3.78e-04, 8.17e-06, 2.90e-06]    [3.61e-04, 8.17e-06, 2.90e-06]    [4.94e-03]
# 47500     [7.36e-06, 1.09e-06, 5.99e-07]    [2.49e-05, 1.09e-06, 5.99e-07]    [1.26e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.823806 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 47500     [7.36e-06, 1.09e-06, 5.99e-07]    [2.49e-05, 1.09e-06, 5.99e-07]    [1.26e-03]
# 48000     [5.03e-04, 5.88e-05, 2.12e-05]    [1.76e-04, 5.88e-05, 2.12e-05]    [1.44e-02]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.877858 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 48000     [5.03e-04, 5.88e-05, 2.12e-05]    [1.76e-04, 5.88e-05, 2.12e-05]    [1.44e-02]
# 48500     [1.17e-04, 1.04e-05, 6.24e-06]    [9.60e-05, 1.04e-05, 6.24e-06]    [7.32e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.995370 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 48500     [1.17e-04, 1.04e-05, 6.24e-06]    [9.60e-05, 1.04e-05, 6.24e-06]    [7.32e-03]
# 49000     [1.44e-04, 7.74e-06, 2.16e-06]    [1.40e-04, 7.74e-06, 2.16e-06]    [4.45e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 1.032025 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 49000     [1.44e-04, 7.74e-06, 2.16e-06]    [1.40e-04, 7.74e-06, 2.16e-06]    [4.45e-03]
# 49500     [1.56e-04, 1.94e-06, 1.73e-06]    [2.08e-04, 1.94e-06, 1.73e-06]    [4.75e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 1.000136 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 49500     [1.56e-04, 1.94e-06, 1.73e-06]    [2.08e-04, 1.94e-06, 1.73e-06]    [4.75e-03]
# 50000     [1.05e-05, 9.04e-07, 6.33e-07]    [3.46e-05, 9.04e-07, 6.33e-07]    [1.27e-03]
#
# Best model at step 36500:
#   train loss: 7.20e-06
#   test loss: 2.89e-05
#   test metric: [1.13e-03]
#
# 'train' took 0.860968 s

# %% [markdown]
# ### Fourier Helper Functions

# %%
def get_fft(y, sampling_rate):
  # Calculate the Fourier transform of f(x)
  fourier = np.fft.fft(y.squeeze())

  length = len(y)

  # Calculate the corresponding frequencies
  freq = np.fft.fftfreq(length, 1/sampling_rate)

  results = list(zip(freq, np.abs(fourier)))
  filtered = [(x, y) for (x, y) in results if x > 0]
  results = list(zip(*filtered))

  return results

# %%
def compare_solutions(t, y_true, y_pred):
  start = int(256 * t * 100)
  end = start + 256

  fig, (ax0, ax1, ax2) = plt.subplots(1, 3, figsize=(20, 5))

  ax0.plot(X[:, 0][start:end], y_true[start:end], "b-", label="Exact")
  ax0.plot(X[:, 0][start:end], y_pred[start:end], "r--", label="Prediction")
  ax0.legend()
  ax0.set_title(f"Comparing Solutions at Time {t}")
  ax0.set_xlabel("x")
  ax0.set_ylabel("u(x, t)")

  true_freq, true_fourier = get_fft(y_true[start:end], 256/2)
  pred_freq, pred_fourier = get_fft(y_pred[start:end], 256/2)
  ax1.plot(true_freq, true_fourier, "b-", label="Exact")
  ax1.plot(pred_freq, pred_fourier, "r--", label="Prediction")
  ax1.legend()
  ax1.set_title(f"Comparing Fourier Transforms of Solutions at Time {t}")
  ax1.set_xlabel("Frequency")
  ax1.set_ylabel("Amplitude")

  fourier_diff = abs(np.array(true_fourier) - np.array(pred_fourier))
  ax2.plot(true_freq, fourier_diff, "b-")
  ax2.set_title(f"Difference in Fourier Transforms of Solutions at Time {t}")
  ax2.set_xlabel("Frequency")
  ax2.set_ylabel("Absolute Difference in Amplitude")
  
  plt.show()

# %%
import pandas as pd
from matplotlib.colors import LogNorm, Normalize

def plot_spectral_dynamics(all_preds, y_true, t):
    fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(20, 8))

    start = int(256 * t * 100)
    end = start + 256
    
    true_freq, true_fourier = get_fft(y_true[start:end], 256/2)

    pct_dict = {"iter": [], "freq": [], "value": []}
    error_dict = {"iter": [], "freq": [], "value": []}
    # Compute spectra for all frames
    for iter, pred in all_preds.items(): 
        if iter % 1000 == 0 or iter == 500:
          pred_freq, pred_fourier = get_fft(pred[start:end], 256/2)
          pct_diff = abs(np.array(pred_fourier) - np.array(true_fourier))/np.array(true_fourier) * 100
          abs_diff = abs(np.array(pred_fourier) - np.array(true_fourier))

          for idx, freq in enumerate(pred_freq):
            pct_dict["iter"].append(iter)
            pct_dict['freq'].append(freq)
            pct_dict['value'].append(pct_diff[idx])

            error_dict["iter"].append(iter)
            error_dict['freq'].append(freq)
            error_dict['value'].append(abs_diff[idx])


    pct_diffs = pd.DataFrame(data = pct_dict)
    pct_diffs = pct_diffs.round(3)
    pct_diffs = pct_diffs.pivot("iter", "freq", "value")
    sns.heatmap(pct_diffs, yticklabels=3, xticklabels=10, vmin=0., vmax=100, cbar_kws={'label': 'Percentage Error in Amplitude'}, ax=ax0, cmap="BuPu")
    ax0.invert_yaxis()
    ax0.set_xlabel("Frequency")
    ax0.set_ylabel("Training Iteration")
    ax0.set_title(f"Frequency Dynamics of Predicted Solution at t = {t}")


    abs_diffs = pd.DataFrame(data = error_dict)
    abs_diffs = abs_diffs.round(3)
    abs_diffs = abs_diffs.pivot("iter", "freq", "value")
    sns.heatmap(abs_diffs, yticklabels=3, xticklabels=10, vmin=0., vmax=max(error_dict['value']), cbar_kws={'label': 'Absolute Error in Amplitude'}, ax=ax1, cmap="BuPu")
    ax1.invert_yaxis()
    ax1.set_xlabel("Frequency")
    ax1.set_ylabel("Training Iteration")
    ax1.set_title(f"Frequency Dynamics of Predicted Solution at t = {t}")

    plt.show()

# %% [markdown]
# ### Visualizations

# %%
import pickle

# compare the true solution with the predicted solution
X, y_true = gen_testdata()

with open('model_preds_diffusion.pkl', 'rb') as f:
    all_preds = pickle.load(f)

# %%
plot_spectral_dynamics(all_preds, y_true, 0.00)
plot_spectral_dynamics(all_preds, y_true, 0.25)
plot_spectral_dynamics(all_preds, y_true, 0.50)
plot_spectral_dynamics(all_preds, y_true, 0.75)
plot_spectral_dynamics(all_preds, y_true, 0.99)
# Out:
# <ipython-input-10-95e140d01a04>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-10-95e140d01a04>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")

# %%
compare_solutions(0, y_true, all_preds[50000])
compare_solutions(0.25, y_true, all_preds[50000])
compare_solutions(0.5, y_true, all_preds[50000])
compare_solutions(0.75, y_true, all_preds[50000])
compare_solutions(0.99, y_true, all_preds[50000])

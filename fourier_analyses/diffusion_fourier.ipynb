# %% [markdown]
# ### Preliminaries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tqdm
import torch
from torch import nn 
import torch.nn.functional as F
from torch import optim
from torch.autograd import grad

from argparse import Namespace
from functools import reduce
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/229 Project'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/229 Project

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### DeepXDE Setup

# %%
# install DeepXDE
# %pip install deepxde
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepxde
#   Downloading DeepXDE-1.8.4-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from deepxde) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.22.4)
# Collecting scikit-optimize>=0.9.0
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.2.2)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->deepxde) (3.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (8.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->deepxde) (3.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)
# Installing collected packages: pyaml, scikit-optimize, deepxde
# Successfully installed deepxde-1.8.4 pyaml-21.10.1 scikit-optimize-0.9.0

# %%
# import packages

from deepxde.backend.set_default_backend import set_default_backend
set_default_backend("tensorflow.compat.v1")

import deepxde as dde
import numpy as np

from deepxde.backend import tf

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
import random
# Out:
# No backend selected.
# Finding available backend...
# Using backend: tensorflow.compat.v1
# Other supported backends: tensorflow, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Found tensorflow.compat.v1
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)
# Enable just-in-time compilation with XLA.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)

# %%
# set up the problem
def pde(x, y):
    dy_t = dde.grad.jacobian(y, x, j=1)
    dy_xx = dde.grad.hessian(y, x, j=0)
    return (
        dy_t
        - dy_xx
        + tf.exp(-x[:, 1:])
        * (tf.sin(np.pi * x[:, 0:1]) - np.pi ** 2 * tf.sin(np.pi * x[:, 0:1]))
    )

def func(x):
    return np.sin(np.pi * x[:, 0:1]) * np.exp(-x[:, 1:])


geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0.5, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

bc = dde.icbc.DirichletBC(geomtime, func, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(geomtime, func, lambda _, on_initial: on_initial)
data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc, ic],
    num_domain=40,
    num_boundary=20,
    num_initial=10,
    solution=func,
    num_test=10000,
)

# %%
# set up the model
layer_size = [2] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

model = dde.Model(data, net)

model.compile("adam", lr=0.001, metrics=["l2 relative error"])
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.084814 s
# /usr/local/lib/python3.9/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:114: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'compile' took 11.596030 s

# %%
def gen_testdata():
  full_domain = np.zeros(shape=(25600, 2))
  true_sol = np.zeros(shape=(25600,))
  for time_step in range(100):
    time = time_step * .01
    x = geom.uniform_points(256, True)
    t = np.full(256, time)
    x = np.hstack((x, t.reshape(-1, 1)))

    start = int(256 * time * 100)
    end = start + 256
    full_domain[start:end] = x

    ground_truth = np.exp(-time) * np.sin(np.pi * x[:, 0])
    true_sol[start:end] = ground_truth
  
  return full_domain, true_sol

# %% [markdown]
# ### Train Model

# %%
import pickle

# train the model
model_preds = {}

for iter in range(500):
  losshistory, train_state = model.train(iterations=1000)
  X, y_true = gen_testdata()
  y_pred = model.predict(X)
  cur_iter = (iter + 1) * 1000
  model_preds[cur_iter] = y_pred

with open('long_model_preds_diffusion.pkl', 'wb') as f:
  pickle.dump(model_preds, f)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.672084 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 116000    [4.30e-05, 2.42e-06, 1.14e-06]    [5.62e-05, 2.42e-06, 1.14e-06]    [2.43e-03]
# 117000    [1.72e-05, 1.86e-06, 6.88e-07]    [2.22e-05, 1.86e-06, 6.88e-07]    [2.27e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.487110 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 117000    [1.72e-05, 1.86e-06, 6.88e-07]    [2.22e-05, 1.86e-06, 6.88e-07]    [2.27e-03]
# 118000    [6.44e-04, 3.73e-05, 1.07e-05]    [5.06e-04, 3.73e-05, 1.07e-05]    [1.03e-02]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.484119 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 118000    [6.44e-04, 3.73e-05, 1.07e-05]    [5.06e-04, 3.73e-05, 1.07e-05]    [1.03e-02]
# 119000    [6.47e-06, 7.34e-07, 3.90e-07]    [2.39e-05, 7.34e-07, 3.90e-07]    [1.40e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.463196 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 119000    [6.47e-06, 7.34e-07, 3.90e-07]    [2.39e-05, 7.34e-07, 3.90e-07]    [1.40e-03]
# 120000    [8.39e-05, 3.56e-06, 7.13e-07]    [6.81e-05, 3.56e-06, 7.13e-07]    [2.94e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.529482 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 120000    [8.39e-05, 3.56e-06, 7.13e-07]    [6.81e-05, 3.56e-06, 7.13e-07]    [2.94e-03]
# 121000    [2.64e-05, 4.02e-06, 2.07e-06]    [5.45e-05, 4.02e-06, 2.07e-06]    [5.32e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.531012 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 121000    [2.64e-05, 4.02e-06, 2.07e-06]    [5.45e-05, 4.02e-06, 2.07e-06]    [5.32e-03]
# 122000    [1.20e-04, 2.74e-06, 1.87e-06]    [1.37e-04, 2.74e-06, 1.87e-06]    [3.45e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.592694 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 122000    [1.20e-04, 2.74e-06, 1.87e-06]    [1.37e-04, 2.74e-06, 1.87e-06]    [3.45e-03]
# 123000    [1.38e-05, 2.27e-07, 1.37e-07]    [4.29e-05, 2.27e-07, 1.37e-07]    [1.25e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 2.002463 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 123000    [1.38e-05, 2.27e-07, 1.37e-07]    [4.29e-05, 2.27e-07, 1.37e-07]    [1.25e-03]
# 124000    [2.11e-04, 7.15e-06, 2.40e-06]    [1.82e-04, 7.15e-06, 2.40e-06]    [4.68e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.861614 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 124000    [2.11e-04, 7.15e-06, 2.40e-06]    [1.82e-04, 7.15e-06, 2.40e-06]    [4.68e-03]
# 125000    [3.07e-04, 1.30e-05, 4.19e-06]    [2.68e-04, 1.30e-05, 4.19e-06]    [6.15e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.523753 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 125000    [3.07e-04, 1.30e-05, 4.19e-06]    [2.68e-04, 1.30e-05, 4.19e-06]    [6.15e-03]
# 126000    [1.38e-05, 4.75e-07, 5.53e-07]    [3.17e-05, 4.75e-07, 5.53e-07]    [1.98e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.516604 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 126000    [1.38e-05, 4.75e-07, 5.53e-07]    [3.17e-05, 4.75e-07, 5.53e-07]    [1.98e-03]
# 127000    [8.62e-06, 4.53e-07, 1.57e-07]    [4.07e-05, 4.54e-07, 1.57e-07]    [1.27e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.623851 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 127000    [8.62e-06, 4.53e-07, 1.57e-07]    [4.07e-05, 4.54e-07, 1.57e-07]    [1.27e-03]
# 128000    [3.20e-06, 2.55e-07, 2.23e-07]    [2.67e-05, 2.55e-07, 2.23e-07]    [6.95e-04]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.541365 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 128000    [3.20e-06, 2.55e-07, 2.23e-07]    [2.67e-05, 2.55e-07, 2.23e-07]    [6.95e-04]
# 129000    [2.83e-06, 2.29e-07, 1.91e-07]    [3.01e-05, 2.30e-07, 1.91e-07]    [9.56e-04]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.529684 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 129000    [2.83e-06, 2.29e-07, 1.91e-07]    [3.01e-05, 2.30e-07, 1.91e-07]    [9.56e-04]
# 130000    [1.09e-05, 6.23e-07, 2.53e-07]    [4.09e-05, 6.23e-07, 2.53e-07]    [1.88e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.605575 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 130000    [1.09e-05, 6.23e-07, 2.53e-07]    [4.09e-05, 6.23e-07, 2.53e-07]    [1.88e-03]
# 131000    [1.12e-05, 5.09e-07, 3.89e-07]    [3.65e-05, 5.09e-07, 3.89e-07]    [1.22e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.985146 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 131000    [1.12e-05, 5.09e-07, 3.89e-07]    [3.65e-05, 5.09e-07, 3.89e-07]    [1.22e-03]
# 132000    [3.25e-05, 3.11e-06, 2.11e-06]    [4.81e-05, 3.11e-06, 2.11e-06]    [4.99e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.897702 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 132000    [3.25e-05, 3.11e-06, 2.11e-06]    [4.81e-05, 3.11e-06, 2.11e-06]    [4.99e-03]
# 133000    [3.73e-06, 2.09e-07, 1.60e-07]    [2.88e-05, 2.09e-07, 1.60e-07]    [8.92e-04]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.545631 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 133000    [3.73e-06, 2.09e-07, 1.60e-07]    [2.88e-05, 2.09e-07, 1.60e-07]    [8.92e-04]
# 134000    [5.43e-06, 3.34e-07, 1.67e-07]    [2.81e-05, 3.34e-07, 1.67e-07]    [7.62e-04]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.565541 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 134000    [5.43e-06, 3.34e-07, 1.67e-07]    [2.81e-05, 3.34e-07, 1.67e-07]    [7.62e-04]
# 135000    [3.98e-05, 5.08e-06, 9.83e-07]    [2.75e-05, 5.08e-06, 9.83e-07]    [3.06e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.591612 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 135000    [3.98e-05, 5.08e-06, 9.83e-07]    [2.75e-05, 5.08e-06, 9.83e-07]    [3.06e-03]
# 136000    [6.37e-05, 7.60e-06, 1.72e-06]    [9.41e-05, 7.60e-06, 1.72e-06]    [4.99e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.573416 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 136000    [6.37e-05, 7.60e-06, 1.72e-06]    [9.41e-05, 7.60e-06, 1.72e-06]    [4.99e-03]
# 137000    [4.55e-06, 3.18e-07, 1.52e-07]    [3.57e-05, 3.18e-07, 1.52e-07]    [1.12e-03]
#
# Best model at step 108000:
#   train loss: 3.05e-06
#   test loss: 2.55e-05
#   test metric: [7.40e-04]
#
# 'train' took 1.581414 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 137000    [4.55e-06, 3.18e-07, 1.52e-07]    [3.57e-05, 3.18e-07, 1.52e-07]    [1.12e-03]
# 138000    [2.39e-06, 1.87e-07, 1.50e-07]    [3.10e-05, 1.87e-07, 1.50e-07]    [8.51e-04]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.613082 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 138000    [2.39e-06, 1.87e-07, 1.50e-07]    [3.10e-05, 1.87e-07, 1.50e-07]    [8.51e-04]
# 139000    [1.64e-05, 6.46e-07, 2.91e-07]    [4.07e-05, 6.46e-07, 2.91e-07]    [1.74e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 2.090341 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 139000    [1.64e-05, 6.46e-07, 2.91e-07]    [4.07e-05, 6.46e-07, 2.91e-07]    [1.74e-03]
# 140000    [5.06e-05, 4.31e-06, 9.21e-07]    [7.62e-05, 4.31e-06, 9.21e-07]    [3.34e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.971091 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 140000    [5.06e-05, 4.31e-06, 9.21e-07]    [7.62e-05, 4.31e-06, 9.21e-07]    [3.34e-03]
# 141000    [2.47e-06, 1.94e-07, 1.92e-07]    [3.23e-05, 1.94e-07, 1.92e-07]    [9.91e-04]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.572652 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 141000    [2.47e-06, 1.94e-07, 1.92e-07]    [3.23e-05, 1.94e-07, 1.92e-07]    [9.91e-04]
# 142000    [6.91e-06, 8.18e-07, 2.57e-07]    [2.86e-05, 8.18e-07, 2.57e-07]    [1.30e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.570707 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 142000    [6.91e-06, 8.18e-07, 2.57e-07]    [2.86e-05, 8.18e-07, 2.57e-07]    [1.30e-03]
# 143000    [2.04e-05, 1.73e-06, 2.78e-07]    [2.82e-05, 1.73e-06, 2.78e-07]    [1.64e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.545993 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 143000    [2.04e-05, 1.73e-06, 2.78e-07]    [2.82e-05, 1.73e-06, 2.78e-07]    [1.64e-03]
# 144000    [2.36e-04, 2.04e-05, 9.13e-06]    [2.41e-04, 2.04e-05, 9.13e-06]    [1.51e-02]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.605405 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 144000    [2.36e-04, 2.04e-05, 9.13e-06]    [2.41e-04, 2.04e-05, 9.13e-06]    [1.51e-02]
# 145000    [1.55e-04, 1.26e-05, 2.55e-06]    [1.58e-04, 1.26e-05, 2.55e-06]    [5.90e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.667874 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 145000    [1.55e-04, 1.26e-05, 2.55e-06]    [1.58e-04, 1.26e-05, 2.55e-06]    [5.90e-03]
# 146000    [3.50e-05, 1.90e-06, 1.72e-06]    [6.92e-05, 1.90e-06, 1.72e-06]    [4.99e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.738851 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 146000    [3.50e-05, 1.90e-06, 1.72e-06]    [6.92e-05, 1.90e-06, 1.72e-06]    [4.99e-03]
# 147000    [5.56e-05, 6.11e-06, 1.91e-06]    [8.40e-05, 6.12e-06, 1.91e-06]    [4.75e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 2.100151 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 147000    [5.56e-05, 6.11e-06, 1.91e-06]    [8.40e-05, 6.12e-06, 1.91e-06]    [4.75e-03]
# 148000    [3.08e-04, 1.81e-05, 4.85e-06]    [2.57e-04, 1.81e-05, 4.85e-06]    [7.69e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.855512 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 148000    [3.08e-04, 1.81e-05, 4.85e-06]    [2.57e-04, 1.81e-05, 4.85e-06]    [7.69e-03]
# 149000    [5.08e-04, 5.50e-05, 1.21e-05]    [3.65e-04, 5.50e-05, 1.21e-05]    [1.17e-02]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.627044 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 149000    [5.08e-04, 5.50e-05, 1.21e-05]    [3.65e-04, 5.50e-05, 1.21e-05]    [1.17e-02]
# 150000    [3.54e-06, 2.94e-07, 1.59e-07]    [3.02e-05, 2.94e-07, 1.59e-07]    [9.16e-04]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.614657 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 150000    [3.54e-06, 2.94e-07, 1.59e-07]    [3.02e-05, 2.94e-07, 1.59e-07]    [9.16e-04]
# 151000    [7.29e-05, 6.26e-06, 3.54e-06]    [8.34e-05, 6.26e-06, 3.54e-06]    [5.98e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.658850 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 151000    [7.29e-05, 6.26e-06, 3.54e-06]    [8.34e-05, 6.26e-06, 3.54e-06]    [5.98e-03]
# 152000    [5.91e-05, 1.04e-06, 3.86e-07]    [9.49e-05, 1.04e-06, 3.86e-07]    [2.27e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.626616 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 152000    [5.91e-05, 1.04e-06, 3.86e-07]    [9.49e-05, 1.04e-06, 3.86e-07]    [2.27e-03]
# 153000    [1.47e-05, 8.86e-07, 3.54e-07]    [3.70e-05, 8.86e-07, 3.54e-07]    [1.02e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.639515 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 153000    [1.47e-05, 8.86e-07, 3.54e-07]    [3.70e-05, 8.86e-07, 3.54e-07]    [1.02e-03]
# 154000    [2.38e-04, 2.49e-05, 5.44e-06]    [1.26e-04, 2.49e-05, 5.44e-06]    [6.92e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 2.004712 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 154000    [2.38e-04, 2.49e-05, 5.44e-06]    [1.26e-04, 2.49e-05, 5.44e-06]    [6.92e-03]
# 155000    [1.90e-05, 9.74e-07, 3.21e-07]    [5.24e-05, 9.74e-07, 3.21e-07]    [1.95e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 2.157924 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 155000    [1.90e-05, 9.74e-07, 3.21e-07]    [5.24e-05, 9.74e-07, 3.21e-07]    [1.95e-03]
# 156000    [2.76e-06, 1.70e-07, 1.27e-07]    [3.34e-05, 1.70e-07, 1.27e-07]    [9.11e-04]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.667309 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 156000    [2.76e-06, 1.70e-07, 1.27e-07]    [3.34e-05, 1.70e-07, 1.27e-07]    [9.11e-04]
# 157000    [2.38e-04, 5.20e-06, 2.32e-06]    [2.56e-04, 5.20e-06, 2.32e-06]    [5.23e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.663640 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 157000    [2.38e-04, 5.20e-06, 2.32e-06]    [2.56e-04, 5.20e-06, 2.32e-06]    [5.23e-03]
# 158000    [1.29e-04, 8.37e-06, 1.55e-05]    [1.83e-04, 8.37e-06, 1.55e-05]    [1.37e-02]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.713463 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 158000    [1.29e-04, 8.37e-06, 1.55e-05]    [1.83e-04, 8.37e-06, 1.55e-05]    [1.37e-02]
# 159000    [7.27e-06, 4.12e-07, 2.32e-07]    [3.43e-05, 4.12e-07, 2.32e-07]    [8.81e-04]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.725493 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 159000    [7.27e-06, 4.12e-07, 2.32e-07]    [3.43e-05, 4.12e-07, 2.32e-07]    [8.81e-04]
# 160000    [2.22e-04, 1.35e-05, 3.37e-06]    [1.28e-04, 1.35e-05, 3.37e-06]    [5.74e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.681242 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 160000    [2.22e-04, 1.35e-05, 3.37e-06]    [1.28e-04, 1.35e-05, 3.37e-06]    [5.74e-03]
# 161000    [4.08e-05, 1.78e-06, 8.33e-07]    [6.12e-05, 1.78e-06, 8.33e-07]    [2.81e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.785111 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 161000    [4.08e-05, 1.78e-06, 8.33e-07]    [6.12e-05, 1.78e-06, 8.33e-07]    [2.81e-03]
# 162000    [9.14e-05, 9.75e-06, 4.21e-06]    [1.14e-04, 9.75e-06, 4.21e-06]    [6.49e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 2.296837 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 162000    [9.14e-05, 9.75e-06, 4.21e-06]    [1.14e-04, 9.75e-06, 4.21e-06]    [6.49e-03]
# 163000    [4.47e-05, 1.84e-06, 7.28e-07]    [6.35e-05, 1.84e-06, 7.28e-07]    [2.57e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.886242 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 163000    [4.47e-05, 1.84e-06, 7.28e-07]    [6.35e-05, 1.84e-06, 7.28e-07]    [2.57e-03]
# 164000    [1.04e-04, 1.18e-05, 1.61e-06]    [5.74e-05, 1.18e-05, 1.61e-06]    [4.56e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.674828 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 164000    [1.04e-04, 1.18e-05, 1.61e-06]    [5.74e-05, 1.18e-05, 1.61e-06]    [4.56e-03]
# 165000    [3.11e-05, 4.03e-06, 2.58e-06]    [6.70e-05, 4.03e-06, 2.58e-06]    [4.50e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.670728 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 165000    [3.11e-05, 4.03e-06, 2.58e-06]    [6.70e-05, 4.03e-06, 2.58e-06]    [4.50e-03]
# 166000    [1.06e-04, 4.68e-06, 1.42e-06]    [1.10e-04, 4.68e-06, 1.42e-06]    [3.59e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.740745 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 166000    [1.06e-04, 4.68e-06, 1.42e-06]    [1.10e-04, 4.68e-06, 1.42e-06]    [3.59e-03]
# 167000    [1.77e-05, 1.96e-06, 6.66e-07]    [4.95e-05, 1.96e-06, 6.66e-07]    [3.22e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.739407 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 167000    [1.77e-05, 1.96e-06, 6.66e-07]    [4.95e-05, 1.96e-06, 6.66e-07]    [3.22e-03]
# 168000    [4.30e-06, 1.30e-07, 2.07e-07]    [3.50e-05, 1.30e-07, 2.07e-07]    [1.05e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 1.733145 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 168000    [4.30e-06, 1.30e-07, 2.07e-07]    [3.50e-05, 1.30e-07, 2.07e-07]    [1.05e-03]
# 169000    [2.99e-05, 3.16e-06, 6.45e-07]    [6.10e-05, 3.16e-06, 6.46e-07]    [3.07e-03]
#
# Best model at step 138000:
#   train loss: 2.72e-06
#   test loss: 3.13e-05
#   test metric: [8.51e-04]
#
# 'train' took 2.255342 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 169000    [2.99e-05, 3.16e-06, 6.45e-07]    [6.10e-05, 3.16e-06, 6.46e-07]    [3.07e-03]
# 170000    [1.60e-06, 1.15e-07, 5.02e-08]    [3.06e-05, 1.15e-07, 5.02e-08]    [7.25e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.090817 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 170000    [1.60e-06, 1.15e-07, 5.02e-08]    [3.06e-05, 1.15e-07, 5.02e-08]    [7.25e-04]
# 171000    [1.39e-05, 7.03e-07, 2.62e-07]    [3.98e-05, 7.03e-07, 2.62e-07]    [1.58e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.711707 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 171000    [1.39e-05, 7.03e-07, 2.62e-07]    [3.98e-05, 7.03e-07, 2.62e-07]    [1.58e-03]
# 172000    [3.92e-04, 4.30e-05, 7.65e-06]    [1.78e-04, 4.30e-05, 7.65e-06]    [9.10e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.774863 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 172000    [3.92e-04, 4.30e-05, 7.65e-06]    [1.78e-04, 4.30e-05, 7.65e-06]    [9.10e-03]
# 173000    [1.90e-06, 1.33e-07, 8.29e-08]    [3.08e-05, 1.33e-07, 8.29e-08]    [6.32e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.728665 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 173000    [1.90e-06, 1.33e-07, 8.29e-08]    [3.08e-05, 1.33e-07, 8.29e-08]    [6.32e-04]
# 174000    [1.74e-06, 1.15e-07, 6.92e-08]    [3.10e-05, 1.15e-07, 6.92e-08]    [7.06e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.674405 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 174000    [1.74e-06, 1.15e-07, 6.92e-08]    [3.10e-05, 1.15e-07, 6.92e-08]    [7.06e-04]
# 175000    [3.14e-06, 1.66e-07, 9.23e-08]    [3.23e-05, 1.67e-07, 9.23e-08]    [7.46e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.704658 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 175000    [3.14e-06, 1.66e-07, 9.23e-08]    [3.23e-05, 1.67e-07, 9.23e-08]    [7.46e-04]
# 176000    [2.91e-06, 2.09e-07, 7.77e-08]    [3.05e-05, 2.09e-07, 7.77e-08]    [8.14e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.165600 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 176000    [2.91e-06, 2.09e-07, 7.77e-08]    [3.05e-05, 2.09e-07, 7.77e-08]    [8.14e-04]
# 177000    [3.25e-05, 5.56e-06, 6.51e-06]    [6.68e-05, 5.56e-06, 6.51e-06]    [7.29e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.231847 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 177000    [3.25e-05, 5.56e-06, 6.51e-06]    [6.68e-05, 5.56e-06, 6.51e-06]    [7.29e-03]
# 178000    [1.15e-05, 8.14e-07, 1.02e-07]    [2.89e-05, 8.14e-07, 1.02e-07]    [1.08e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.785746 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 178000    [1.15e-05, 8.14e-07, 1.02e-07]    [2.89e-05, 8.14e-07, 1.02e-07]    [1.08e-03]
# 179000    [5.20e-06, 1.45e-07, 1.33e-07]    [3.49e-05, 1.45e-07, 1.33e-07]    [9.14e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.733043 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 179000    [5.20e-06, 1.45e-07, 1.33e-07]    [3.49e-05, 1.45e-07, 1.33e-07]    [9.14e-04]
# 180000    [4.09e-04, 4.62e-06, 7.92e-06]    [4.92e-04, 4.62e-06, 7.92e-06]    [9.28e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.736772 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 180000    [4.09e-04, 4.62e-06, 7.92e-06]    [4.92e-04, 4.62e-06, 7.92e-06]    [9.28e-03]
# 181000    [1.00e-04, 1.23e-05, 4.17e-06]    [1.16e-04, 1.23e-05, 4.17e-06]    [6.72e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.770861 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 181000    [1.00e-04, 1.23e-05, 4.17e-06]    [1.16e-04, 1.23e-05, 4.17e-06]    [6.72e-03]
# 182000    [4.41e-05, 2.69e-06, 6.31e-07]    [7.70e-05, 2.69e-06, 6.32e-07]    [3.09e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.721250 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 182000    [4.41e-05, 2.69e-06, 6.31e-07]    [7.70e-05, 2.69e-06, 6.32e-07]    [3.09e-03]
# 183000    [1.65e-06, 1.44e-07, 5.25e-08]    [3.03e-05, 1.44e-07, 5.25e-08]    [5.48e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.032680 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 183000    [1.65e-06, 1.44e-07, 5.25e-08]    [3.03e-05, 1.44e-07, 5.25e-08]    [5.48e-04]
# 184000    [1.11e-05, 2.58e-07, 5.45e-07]    [4.30e-05, 2.58e-07, 5.45e-07]    [1.82e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.325432 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 184000    [1.11e-05, 2.58e-07, 5.45e-07]    [4.30e-05, 2.58e-07, 5.45e-07]    [1.82e-03]
# 185000    [5.27e-05, 4.20e-06, 5.75e-07]    [8.63e-05, 4.20e-06, 5.75e-07]    [3.52e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.794685 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 185000    [5.27e-05, 4.20e-06, 5.75e-07]    [8.63e-05, 4.20e-06, 5.75e-07]    [3.52e-03]
# 186000    [6.35e-06, 2.12e-07, 2.26e-08]    [3.80e-05, 2.12e-07, 2.26e-08]    [1.38e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.751185 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 186000    [6.35e-06, 2.12e-07, 2.26e-08]    [3.80e-05, 2.12e-07, 2.26e-08]    [1.38e-03]
# 187000    [2.42e-06, 1.81e-07, 5.20e-08]    [3.06e-05, 1.81e-07, 5.20e-08]    [5.66e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.737338 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 187000    [2.42e-06, 1.81e-07, 5.20e-08]    [3.06e-05, 1.81e-07, 5.20e-08]    [5.66e-04]
# 188000    [2.70e-05, 2.70e-06, 3.87e-07]    [3.18e-05, 2.70e-06, 3.87e-07]    [2.04e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.830231 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 188000    [2.70e-05, 2.70e-06, 3.87e-07]    [3.18e-05, 2.70e-06, 3.87e-07]    [2.04e-03]
# 189000    [7.97e-06, 4.95e-07, 2.78e-07]    [3.68e-05, 4.95e-07, 2.78e-07]    [2.40e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.783591 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 189000    [7.97e-06, 4.95e-07, 2.78e-07]    [3.68e-05, 4.95e-07, 2.78e-07]    [2.40e-03]
# 190000    [5.06e-06, 2.38e-07, 1.04e-07]    [3.47e-05, 2.38e-07, 1.04e-07]    [1.03e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.034533 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 190000    [5.06e-06, 2.38e-07, 1.04e-07]    [3.47e-05, 2.38e-07, 1.04e-07]    [1.03e-03]
# 191000    [4.42e-05, 2.24e-06, 3.69e-07]    [4.60e-05, 2.24e-06, 3.69e-07]    [2.21e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.391084 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 191000    [4.42e-05, 2.24e-06, 3.69e-07]    [4.60e-05, 2.24e-06, 3.69e-07]    [2.21e-03]
# 192000    [1.05e-04, 9.28e-06, 1.35e-06]    [1.37e-04, 9.28e-06, 1.35e-06]    [4.60e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.860873 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 192000    [1.05e-04, 9.28e-06, 1.35e-06]    [1.37e-04, 9.28e-06, 1.35e-06]    [4.60e-03]
# 193000    [3.83e-05, 1.97e-06, 5.70e-07]    [6.00e-05, 1.97e-06, 5.70e-07]    [2.41e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.840816 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 193000    [3.83e-05, 1.97e-06, 5.70e-07]    [6.00e-05, 1.97e-06, 5.70e-07]    [2.41e-03]
# 194000    [3.04e-05, 3.36e-06, 6.17e-07]    [6.70e-05, 3.36e-06, 6.17e-07]    [3.11e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.906484 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 194000    [3.04e-05, 3.36e-06, 6.17e-07]    [6.70e-05, 3.36e-06, 6.17e-07]    [3.11e-03]
# 195000    [2.28e-06, 1.81e-07, 9.44e-08]    [3.59e-05, 1.81e-07, 9.44e-08]    [9.78e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.808800 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 195000    [2.28e-06, 1.81e-07, 9.44e-08]    [3.59e-05, 1.81e-07, 9.44e-08]    [9.78e-04]
# 196000    [3.02e-05, 3.03e-06, 4.12e-07]    [4.32e-05, 3.03e-06, 4.12e-07]    [1.91e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.805024 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 196000    [3.02e-05, 3.03e-06, 4.12e-07]    [4.32e-05, 3.03e-06, 4.12e-07]    [1.91e-03]
# 197000    [2.19e-05, 8.96e-07, 1.19e-06]    [5.54e-05, 8.96e-07, 1.19e-06]    [3.76e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.259812 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 197000    [2.19e-05, 8.96e-07, 1.19e-06]    [5.54e-05, 8.96e-07, 1.19e-06]    [3.76e-03]
# 198000    [7.58e-06, 5.96e-07, 1.60e-07]    [3.20e-05, 5.96e-07, 1.60e-07]    [1.54e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 2.355638 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 198000    [7.58e-06, 5.96e-07, 1.60e-07]    [3.20e-05, 5.96e-07, 1.60e-07]    [1.54e-03]
# 199000    [2.78e-05, 2.43e-06, 9.24e-07]    [4.22e-05, 2.43e-06, 9.24e-07]    [2.83e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.854730 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 199000    [2.78e-05, 2.43e-06, 9.24e-07]    [4.22e-05, 2.43e-06, 9.24e-07]    [2.83e-03]
# 200000    [2.55e-06, 2.28e-07, 3.08e-08]    [3.03e-05, 2.28e-07, 3.08e-08]    [5.50e-04]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.816979 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 200000    [2.55e-06, 2.28e-07, 3.08e-08]    [3.03e-05, 2.28e-07, 3.08e-08]    [5.50e-04]
# 201000    [1.54e-04, 6.83e-06, 2.73e-06]    [1.35e-04, 6.83e-06, 2.73e-06]    [4.02e-03]
#
# Best model at step 170000:
#   train loss: 1.77e-06
#   test loss: 3.07e-05
#   test metric: [7.25e-04]
#
# 'train' took 1.842701 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 201000    [1.54e-04, 6.83e-06, 2.73e-06]    [1.35e-04, 6.83e-06, 2.73e-06]    [4.02e-03]
# 202000    [1.46e-06, 8.88e-08, 4.37e-08]    [3.33e-05, 8.88e-08, 4.37e-08]    [6.16e-04]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.916311 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 202000    [1.46e-06, 8.88e-08, 4.37e-08]    [3.33e-05, 8.88e-08, 4.37e-08]    [6.16e-04]
# 203000    [3.44e-06, 2.52e-07, 6.33e-08]    [3.82e-05, 2.52e-07, 6.33e-08]    [9.84e-04]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.879397 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 203000    [3.44e-06, 2.52e-07, 6.33e-08]    [3.82e-05, 2.52e-07, 6.33e-08]    [9.84e-04]
# 204000    [2.42e-05, 1.73e-06, 1.75e-06]    [6.26e-05, 1.73e-06, 1.75e-06]    [4.21e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 2.536188 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 204000    [2.42e-05, 1.73e-06, 1.75e-06]    [6.26e-05, 1.73e-06, 1.75e-06]    [4.21e-03]
# 205000    [1.19e-04, 5.69e-06, 8.94e-07]    [9.04e-05, 5.69e-06, 8.94e-07]    [3.83e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 2.141853 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 205000    [1.19e-04, 5.69e-06, 8.94e-07]    [9.04e-05, 5.69e-06, 8.94e-07]    [3.83e-03]
# 206000    [4.51e-06, 3.99e-07, 2.34e-07]    [3.74e-05, 3.99e-07, 2.34e-07]    [1.51e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.828122 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 206000    [4.51e-06, 3.99e-07, 2.34e-07]    [3.74e-05, 3.99e-07, 2.34e-07]    [1.51e-03]
# 207000    [1.89e-05, 2.00e-06, 1.22e-06]    [4.39e-05, 2.00e-06, 1.22e-06]    [3.37e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.985252 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 207000    [1.89e-05, 2.00e-06, 1.22e-06]    [4.39e-05, 2.00e-06, 1.22e-06]    [3.37e-03]
# 208000    [3.84e-06, 2.57e-07, 3.03e-08]    [3.19e-05, 2.57e-07, 3.03e-08]    [6.34e-04]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 2.188711 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 208000    [3.84e-06, 2.57e-07, 3.03e-08]    [3.19e-05, 2.57e-07, 3.03e-08]    [6.34e-04]
# 209000    [2.80e-05, 3.78e-06, 1.02e-06]    [6.58e-05, 3.78e-06, 1.02e-06]    [4.05e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.883189 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 209000    [2.80e-05, 3.78e-06, 1.02e-06]    [6.58e-05, 3.78e-06, 1.02e-06]    [4.05e-03]
# 210000    [1.84e-06, 1.21e-07, 2.24e-08]    [3.49e-05, 1.21e-07, 2.24e-08]    [8.31e-04]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 2.231812 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 210000    [1.84e-06, 1.21e-07, 2.24e-08]    [3.49e-05, 1.21e-07, 2.24e-08]    [8.31e-04]
# 211000    [1.96e-05, 2.70e-06, 1.80e-06]    [3.47e-05, 2.70e-06, 1.80e-06]    [4.12e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 2.468331 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 211000    [1.96e-05, 2.70e-06, 1.80e-06]    [3.47e-05, 2.70e-06, 1.80e-06]    [4.12e-03]
# 212000    [9.07e-06, 7.24e-07, 5.03e-08]    [2.95e-05, 7.24e-07, 5.03e-08]    [1.23e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.969862 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 212000    [9.07e-06, 7.24e-07, 5.03e-08]    [2.95e-05, 7.24e-07, 5.03e-08]    [1.23e-03]
# 213000    [3.84e-05, 2.05e-06, 1.90e-06]    [8.23e-05, 2.05e-06, 1.90e-06]    [3.11e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 3.282550 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 213000    [3.84e-05, 2.05e-06, 1.90e-06]    [8.23e-05, 2.05e-06, 1.90e-06]    [3.11e-03]
# 214000    [4.83e-05, 1.53e-06, 5.76e-07]    [7.69e-05, 1.53e-06, 5.76e-07]    [2.32e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.945143 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 214000    [4.83e-05, 1.53e-06, 5.76e-07]    [7.69e-05, 1.53e-06, 5.76e-07]    [2.32e-03]
# 215000    [1.59e-05, 7.63e-07, 3.27e-07]    [4.99e-05, 7.63e-07, 3.27e-07]    [1.97e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.903855 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 215000    [1.59e-05, 7.63e-07, 3.27e-07]    [4.99e-05, 7.63e-07, 3.27e-07]    [1.97e-03]
# 216000    [1.08e-05, 5.59e-07, 2.18e-07]    [4.34e-05, 5.59e-07, 2.18e-07]    [1.82e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 2.520390 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 216000    [1.08e-05, 5.59e-07, 2.18e-07]    [4.34e-05, 5.59e-07, 2.18e-07]    [1.82e-03]
# 217000    [2.29e-04, 8.87e-06, 1.22e-05]    [2.64e-04, 8.87e-06, 1.22e-05]    [1.09e-02]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 2.352277 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 217000    [2.29e-04, 8.87e-06, 1.22e-05]    [2.64e-04, 8.87e-06, 1.22e-05]    [1.09e-02]
# 218000    [7.82e-05, 5.63e-06, 5.95e-07]    [5.97e-05, 5.63e-06, 5.95e-07]    [3.34e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.911649 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 218000    [7.82e-05, 5.63e-06, 5.95e-07]    [5.97e-05, 5.63e-06, 5.95e-07]    [3.34e-03]
# 219000    [9.52e-06, 1.36e-07, 2.65e-07]    [4.53e-05, 1.36e-07, 2.64e-07]    [1.27e-03]
#
# Best model at step 202000:
#   train loss: 1.59e-06
#   test loss: 3.34e-05
#   test metric: [6.16e-04]
#
# 'train' took 1.910374 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 219000    [9.52e-06, 1.36e-07, 2.65e-07]    [4.53e-05, 1.36e-07, 2.64e-07]    [1.27e-03]
# 220000    [1.33e-06, 1.10e-07, 1.16e-08]    [3.10e-05, 1.10e-07, 1.16e-08]    [4.42e-04]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 1.931043 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 220000    [1.33e-06, 1.10e-07, 1.16e-08]    [3.10e-05, 1.10e-07, 1.16e-08]    [4.42e-04]
# 221000    [2.49e-06, 1.39e-07, 2.55e-08]    [3.26e-05, 1.39e-07, 2.55e-08]    [4.79e-04]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 1.934037 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 221000    [2.49e-06, 1.39e-07, 2.55e-08]    [3.26e-05, 1.39e-07, 2.55e-08]    [4.79e-04]
# 222000    [1.91e-04, 6.68e-06, 2.37e-06]    [2.19e-04, 6.68e-06, 2.37e-06]    [4.72e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 2.153225 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 222000    [1.91e-04, 6.68e-06, 2.37e-06]    [2.19e-04, 6.68e-06, 2.37e-06]    [4.72e-03]
# 223000    [4.71e-04, 1.70e-05, 6.79e-06]    [3.71e-04, 1.70e-05, 6.79e-06]    [6.79e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 2.568712 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 223000    [4.71e-04, 1.70e-05, 6.79e-06]    [3.71e-04, 1.70e-05, 6.79e-06]    [6.79e-03]
# 224000    [4.82e-06, 2.77e-07, 9.22e-08]    [4.02e-05, 2.77e-07, 9.22e-08]    [1.25e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 1.985519 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 224000    [4.82e-06, 2.77e-07, 9.22e-08]    [4.02e-05, 2.77e-07, 9.22e-08]    [1.25e-03]
# 225000    [1.30e-05, 1.16e-06, 1.11e-07]    [2.93e-05, 1.16e-06, 1.11e-07]    [1.40e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 1.940940 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 225000    [1.30e-05, 1.16e-06, 1.11e-07]    [2.93e-05, 1.16e-06, 1.11e-07]    [1.40e-03]
# 226000    [6.88e-05, 3.29e-06, 9.95e-07]    [8.17e-05, 3.29e-06, 9.95e-07]    [3.36e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 1.959238 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 226000    [6.88e-05, 3.29e-06, 9.95e-07]    [8.17e-05, 3.29e-06, 9.95e-07]    [3.36e-03]
# 227000    [5.07e-06, 3.93e-07, 1.98e-07]    [3.80e-05, 3.93e-07, 1.98e-07]    [1.48e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 1.961620 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 227000    [5.07e-06, 3.93e-07, 1.98e-07]    [3.80e-05, 3.93e-07, 1.98e-07]    [1.48e-03]
# 228000    [5.03e-05, 1.18e-06, 2.19e-06]    [9.11e-05, 1.18e-06, 2.19e-06]    [4.29e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 2.076591 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 228000    [5.03e-05, 1.18e-06, 2.19e-06]    [9.11e-05, 1.18e-06, 2.19e-06]    [4.29e-03]
# 229000    [2.06e-05, 1.68e-06, 1.36e-06]    [6.17e-05, 1.68e-06, 1.36e-06]    [3.86e-03]
#
# Best model at step 220000:
#   train loss: 1.45e-06
#   test loss: 3.11e-05
#   test metric: [4.42e-04]
#
# 'train' took 2.676296 s
#
# Training model...
#
# ...
# 462000    [1.18e-06, 1.05e-07, 3.39e-08]    [1.40e-04, 1.05e-07, 3.39e-08]    [7.48e-04]
# 463000    [3.30e-05, 1.59e-06, 4.48e-07]    [1.82e-04, 1.59e-06, 4.48e-07]    [2.44e-03]
#
# Best model at step 391000:
#   train loss: 7.13e-07
#   test loss: 9.46e-05
#   test metric: [7.18e-04]
#
# 'train' took 3.966184 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 463000    [3.30e-05, 1.59e-06, 4.48e-07]    [1.82e-04, 1.59e-06, 4.48e-07]    [2.44e-03]
# 464000    [7.41e-05, 1.45e-06, 1.77e-07]    [2.78e-04, 1.45e-06, 1.77e-07]    [2.99e-03]
#
# Best model at step 391000:
#   train loss: 7.13e-07
#   test loss: 9.46e-05
#   test metric: [7.18e-04]
#
# 'train' took 3.303746 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 464000    [7.41e-05, 1.45e-06, 1.77e-07]    [2.78e-04, 1.45e-06, 1.77e-07]    [2.99e-03]
# 465000    [4.09e-06, 2.26e-07, 4.90e-08]    [1.41e-04, 2.26e-07, 4.90e-08]    [8.56e-04]
#
# Best model at step 391000:
#   train loss: 7.13e-07
#   test loss: 9.46e-05
#   test metric: [7.18e-04]
#
# 'train' took 3.281888 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 465000    [4.09e-06, 2.26e-07, 4.90e-08]    [1.41e-04, 2.26e-07, 4.90e-08]    [8.56e-04]
# 466000    [5.68e-07, 6.04e-08, 1.38e-08]    [1.47e-04, 6.04e-08, 1.38e-08]    [6.40e-04]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 4.010166 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 466000    [5.68e-07, 6.04e-08, 1.38e-08]    [1.47e-04, 6.04e-08, 1.38e-08]    [6.40e-04]
# 467000    [3.35e-05, 2.70e-06, 1.69e-06]    [1.76e-04, 2.70e-06, 1.69e-06]    [3.70e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.802164 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 467000    [3.35e-05, 2.70e-06, 1.69e-06]    [1.76e-04, 2.70e-06, 1.69e-06]    [3.70e-03]
# 468000    [7.83e-06, 1.51e-07, 2.65e-07]    [1.59e-04, 1.51e-07, 2.65e-07]    [1.84e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.472585 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 468000    [7.83e-06, 1.51e-07, 2.65e-07]    [1.59e-04, 1.51e-07, 2.65e-07]    [1.84e-03]
# 469000    [1.60e-05, 2.94e-06, 8.36e-07]    [1.38e-04, 2.94e-06, 8.36e-07]    [2.68e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.482167 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 469000    [1.60e-05, 2.94e-06, 8.36e-07]    [1.38e-04, 2.94e-06, 8.36e-07]    [2.68e-03]
# 470000    [4.22e-05, 1.16e-06, 5.99e-07]    [2.03e-04, 1.16e-06, 5.99e-07]    [2.54e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 4.427404 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 470000    [4.22e-05, 1.16e-06, 5.99e-07]    [2.03e-04, 1.16e-06, 5.99e-07]    [2.54e-03]
# 471000    [8.08e-05, 4.50e-07, 1.31e-06]    [2.71e-04, 4.50e-07, 1.31e-06]    [3.94e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.396026 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 471000    [8.08e-05, 4.50e-07, 1.31e-06]    [2.71e-04, 4.50e-07, 1.31e-06]    [3.94e-03]
# 472000    [1.65e-06, 2.56e-07, 1.88e-07]    [1.50e-04, 2.56e-07, 1.88e-07]    [9.79e-04]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.482618 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 472000    [1.65e-06, 2.56e-07, 1.88e-07]    [1.50e-04, 2.56e-07, 1.88e-07]    [9.79e-04]
# 473000    [1.74e-04, 1.14e-05, 1.80e-06]    [1.93e-04, 1.14e-05, 1.80e-06]    [5.42e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.721649 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 473000    [1.74e-04, 1.14e-05, 1.80e-06]    [1.93e-04, 1.14e-05, 1.80e-06]    [5.42e-03]
# 474000    [6.71e-07, 1.04e-07, 7.01e-08]    [1.52e-04, 1.04e-07, 7.01e-08]    [9.19e-04]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.968167 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 474000    [6.71e-07, 1.04e-07, 7.01e-08]    [1.52e-04, 1.04e-07, 7.01e-08]    [9.19e-04]
# 475000    [2.07e-04, 5.17e-06, 2.32e-06]    [3.32e-04, 5.17e-06, 2.32e-06]    [3.95e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.348892 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 475000    [2.07e-04, 5.17e-06, 2.32e-06]    [3.32e-04, 5.17e-06, 2.32e-06]    [3.95e-03]
# 476000    [1.32e-06, 1.09e-07, 1.65e-08]    [1.50e-04, 1.09e-07, 1.66e-08]    [6.22e-04]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.340206 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 476000    [1.32e-06, 1.09e-07, 1.65e-08]    [1.50e-04, 1.09e-07, 1.66e-08]    [6.22e-04]
# 477000    [3.16e-06, 8.84e-08, 5.24e-08]    [1.56e-04, 8.84e-08, 5.24e-08]    [1.06e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 4.381727 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 477000    [3.16e-06, 8.84e-08, 5.24e-08]    [1.56e-04, 8.84e-08, 5.24e-08]    [1.06e-03]
# 478000    [1.36e-05, 4.19e-07, 1.77e-07]    [1.68e-04, 4.19e-07, 1.77e-07]    [1.57e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.628561 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 478000    [1.36e-05, 4.19e-07, 1.77e-07]    [1.68e-04, 4.19e-07, 1.77e-07]    [1.57e-03]
# 479000    [8.79e-06, 3.32e-07, 2.19e-08]    [1.87e-04, 3.32e-07, 2.19e-08]    [1.31e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.536849 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 479000    [8.79e-06, 3.32e-07, 2.19e-08]    [1.87e-04, 3.32e-07, 2.19e-08]    [1.31e-03]
# 480000    [8.65e-07, 5.62e-08, 1.84e-08]    [1.55e-04, 5.62e-08, 1.84e-08]    [7.91e-04]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.768642 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 480000    [8.65e-07, 5.62e-08, 1.84e-08]    [1.55e-04, 5.62e-08, 1.84e-08]    [7.91e-04]
# 481000    [5.72e-06, 3.52e-07, 5.94e-08]    [1.54e-04, 3.52e-07, 5.94e-08]    [9.49e-04]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 4.267371 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 481000    [5.72e-06, 3.52e-07, 5.94e-08]    [1.54e-04, 3.52e-07, 5.94e-08]    [9.49e-04]
# 482000    [8.83e-07, 7.63e-08, 1.82e-08]    [1.53e-04, 7.63e-08, 1.82e-08]    [6.64e-04]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.564480 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 482000    [8.83e-07, 7.63e-08, 1.82e-08]    [1.53e-04, 7.63e-08, 1.82e-08]    [6.64e-04]
# 483000    [5.62e-06, 9.28e-07, 2.04e-07]    [1.38e-04, 9.28e-07, 2.04e-07]    [1.19e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 3.388363 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 483000    [5.62e-06, 9.28e-07, 2.04e-07]    [1.38e-04, 9.28e-07, 2.04e-07]    [1.19e-03]
# 484000    [1.54e-05, 2.62e-06, 1.03e-06]    [1.65e-04, 2.62e-06, 1.03e-06]    [2.79e-03]
#
# Best model at step 466000:
#   train loss: 6.42e-07
#   test loss: 1.47e-04
#   test metric: [6.40e-04]
#
# 'train' took 4.200195 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 484000    [1.54e-05, 2.62e-06, 1.03e-06]    [1.65e-04, 2.62e-06, 1.03e-06]    [2.79e-03]
# 485000    [5.46e-07, 5.37e-08, 1.81e-08]    [1.55e-04, 5.37e-08, 1.81e-08]    [8.65e-04]
#
# Best model at step 485000:
#   train loss: 6.18e-07
#   test loss: 1.55e-04
#   test metric: [8.65e-04]
#
# 'train' took 3.453306 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 485000    [5.46e-07, 5.37e-08, 1.81e-08]    [1.55e-04, 5.37e-08, 1.81e-08]    [8.65e-04]
# 486000    [8.07e-07, 1.60e-07, 7.07e-08]    [1.56e-04, 1.60e-07, 7.07e-08]    [6.87e-04]
#
# Best model at step 485000:
#   train loss: 6.18e-07
#   test loss: 1.55e-04
#   test metric: [8.65e-04]
#
# 'train' took 3.516642 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 486000    [8.07e-07, 1.60e-07, 7.07e-08]    [1.56e-04, 1.60e-07, 7.07e-08]    [6.87e-04]
# 487000    [2.11e-04, 1.92e-05, 2.63e-06]    [1.84e-04, 1.92e-05, 2.63e-06]    [6.80e-03]
#
# Best model at step 485000:
#   train loss: 6.18e-07
#   test loss: 1.55e-04
#   test metric: [8.65e-04]
#
# 'train' took 3.533805 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 487000    [2.11e-04, 1.92e-05, 2.63e-06]    [1.84e-04, 1.92e-05, 2.63e-06]    [6.80e-03]
# 488000    [1.03e-04, 4.15e-06, 1.71e-06]    [2.23e-04, 4.15e-06, 1.71e-06]    [4.02e-03]
#
# Best model at step 485000:
#   train loss: 6.18e-07
#   test loss: 1.55e-04
#   test metric: [8.65e-04]
#
# 'train' took 4.393156 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 488000    [1.03e-04, 4.15e-06, 1.71e-06]    [2.23e-04, 4.15e-06, 1.71e-06]    [4.02e-03]
# 489000    [4.01e-05, 7.25e-07, 1.23e-06]    [1.93e-04, 7.24e-07, 1.23e-06]    [3.47e-03]
#
# Best model at step 485000:
#   train loss: 6.18e-07
#   test loss: 1.55e-04
#   test metric: [8.65e-04]
#
# 'train' took 3.528063 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 489000    [4.01e-05, 7.25e-07, 1.23e-06]    [1.93e-04, 7.24e-07, 1.23e-06]    [3.47e-03]
# 490000    [1.43e-05, 8.55e-07, 6.49e-08]    [1.95e-04, 8.55e-07, 6.49e-08]    [1.89e-03]
#
# Best model at step 485000:
#   train loss: 6.18e-07
#   test loss: 1.55e-04
#   test metric: [8.65e-04]
#
# 'train' took 3.469668 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 490000    [1.43e-05, 8.55e-07, 6.49e-08]    [1.95e-04, 8.55e-07, 6.49e-08]    [1.89e-03]
# 491000    [2.88e-05, 1.53e-06, 1.49e-07]    [2.20e-04, 1.53e-06, 1.49e-07]    [2.02e-03]
#
# Best model at step 485000:
#   train loss: 6.18e-07
#   test loss: 1.55e-04
#   test metric: [8.65e-04]
#
# 'train' took 4.167418 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 491000    [2.88e-05, 1.53e-06, 1.49e-07]    [2.20e-04, 1.53e-06, 1.49e-07]    [2.02e-03]
# 492000    [5.18e-07, 5.42e-08, 1.93e-08]    [1.60e-04, 5.42e-08, 1.93e-08]    [8.16e-04]
#
# Best model at step 492000:
#   train loss: 5.91e-07
#   test loss: 1.61e-04
#   test metric: [8.16e-04]
#
# 'train' took 3.743328 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 492000    [5.18e-07, 5.42e-08, 1.93e-08]    [1.60e-04, 5.42e-08, 1.93e-08]    [8.16e-04]
# 493000    [3.04e-06, 1.53e-07, 1.51e-07]    [1.59e-04, 1.53e-07, 1.51e-07]    [1.03e-03]
#
# Best model at step 492000:
#   train loss: 5.91e-07
#   test loss: 1.61e-04
#   test metric: [8.16e-04]
#
# 'train' took 3.554905 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 493000    [3.04e-06, 1.53e-07, 1.51e-07]    [1.59e-04, 1.53e-07, 1.51e-07]    [1.03e-03]
# 494000    [3.08e-05, 1.66e-06, 3.68e-06]    [1.77e-04, 1.66e-06, 3.68e-06]    [4.72e-03]
#
# Best model at step 492000:
#   train loss: 5.91e-07
#   test loss: 1.61e-04
#   test metric: [8.16e-04]
#
# 'train' took 3.698776 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 494000    [3.08e-05, 1.66e-06, 3.68e-06]    [1.77e-04, 1.66e-06, 3.68e-06]    [4.72e-03]
# 495000    [6.66e-07, 5.91e-08, 7.75e-09]    [1.62e-04, 5.91e-08, 7.74e-09]    [7.24e-04]
#
# Best model at step 492000:
#   train loss: 5.91e-07
#   test loss: 1.61e-04
#   test metric: [8.16e-04]
#
# 'train' took 4.283062 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 495000    [6.66e-07, 5.91e-08, 7.75e-09]    [1.62e-04, 5.91e-08, 7.74e-09]    [7.24e-04]
# 496000    [2.78e-05, 4.24e-07, 1.66e-06]    [2.16e-04, 4.24e-07, 1.66e-06]    [2.49e-03]
#
# Best model at step 492000:
#   train loss: 5.91e-07
#   test loss: 1.61e-04
#   test metric: [8.16e-04]
#
# 'train' took 3.543720 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 496000    [2.78e-05, 4.24e-07, 1.66e-06]    [2.16e-04, 4.24e-07, 1.66e-06]    [2.49e-03]
# 497000    [4.53e-07, 5.13e-08, 1.01e-08]    [1.59e-04, 5.13e-08, 1.01e-08]    [7.38e-04]
#
# Best model at step 497000:
#   train loss: 5.14e-07
#   test loss: 1.60e-04
#   test metric: [7.38e-04]
#
# 'train' took 3.548155 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 497000    [4.53e-07, 5.13e-08, 1.01e-08]    [1.59e-04, 5.13e-08, 1.01e-08]    [7.38e-04]
# 498000    [9.98e-07, 5.31e-08, 1.77e-08]    [1.61e-04, 5.31e-08, 1.77e-08]    [8.95e-04]
#
# Best model at step 497000:
#   train loss: 5.14e-07
#   test loss: 1.60e-04
#   test metric: [7.38e-04]
#
# 'train' took 4.306672 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 498000    [9.98e-07, 5.31e-08, 1.77e-08]    [1.61e-04, 5.31e-08, 1.77e-08]    [8.95e-04]
# 499000    [1.42e-04, 7.44e-06, 2.64e-06]    [2.62e-04, 7.44e-06, 2.64e-06]    [4.78e-03]
#
# Best model at step 497000:
#   train loss: 5.14e-07
#   test loss: 1.60e-04
#   test metric: [7.38e-04]
#
# 'train' took 3.550837 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 499000    [1.42e-04, 7.44e-06, 2.64e-06]    [2.62e-04, 7.44e-06, 2.64e-06]    [4.78e-03]
# 500000    [3.38e-06, 3.54e-07, 1.03e-07]    [1.82e-04, 3.54e-07, 1.03e-07]    [1.47e-03]
#
# Best model at step 497000:
#   train loss: 5.14e-07
#   test loss: 1.60e-04
#   test metric: [7.38e-04]
#
# 'train' took 3.598239 s

# %% [markdown]
# ### Fourier Helper Functions

# %%
def get_fft(y, sampling_rate):
  # Calculate the Fourier transform of f(x)
  fourier = np.fft.fft(y.squeeze())

  length = len(y)

  # Calculate the corresponding frequencies
  freq = np.fft.fftfreq(length, 1/sampling_rate)

  results = list(zip(freq, np.abs(fourier)))
  filtered = [(x, y) for (x, y) in results if x > 0]
  results = list(zip(*filtered))

  return results

# %%
def compare_solutions(t, y_true, y_pred, domain_len):
  start = int(256 * t * 100)
  end = start + 256

  fig, (ax0, ax1, ax2) = plt.subplots(1, 3, figsize=(20, 5))

  ax0.plot(X[:, 0][start:end], y_true[start:end], "b-", label="Exact")
  ax0.plot(X[:, 0][start:end], y_pred[start:end], "r--", label="Prediction")
  ax0.legend()
  ax0.set_title(f"Comparing Solutions at Time {t}")
  ax0.set_xlabel("x")
  ax0.set_ylabel("u(x, t)")

  true_freq, true_fourier = get_fft(y_true[start:end], 256/domain_len)
  pred_freq, pred_fourier = get_fft(y_pred[start:end], 256/domain_len)
  ax1.plot(true_freq, true_fourier, "b-", label="Exact")
  ax1.plot(pred_freq, pred_fourier, "r--", label="Prediction")
  ax1.legend()
  ax1.set_title(f"Comparing Fourier Transforms of Solutions at Time {t}")
  ax1.set_xlabel("Frequency")
  ax1.set_ylabel("Amplitude")

  fourier_diff = abs(np.array(true_fourier) - np.array(pred_fourier))
  ax2.plot(true_freq, fourier_diff, "b-")
  ax2.set_title(f"Difference in Fourier Transforms of Solutions at Time {t}")
  ax2.set_xlabel("Frequency")
  ax2.set_ylabel("Absolute Difference in Amplitude")
  
  plt.show()

# %%
import pandas as pd
from matplotlib.colors import LogNorm, Normalize

def plot_spectral_dynamics(all_preds, y_true, t, domain_len):
    fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(20, 8))

    start = int(256 * t * 100)
    end = start + 256
    
    true_freq, true_fourier = get_fft(y_true[start:end], 256/domain_len)

    pct_dict = {"iter": [], "freq": [], "value": []}
    error_dict = {"iter": [], "freq": [], "value": []}
    # Compute spectra for all frames
    for iter, pred in all_preds.items(): 
        if iter % 1000 == 0 or iter == 500:
          pred_freq, pred_fourier = get_fft(pred[start:end], 256/domain_len)
          pct_diff = abs(np.array(pred_fourier) - np.array(true_fourier))/np.array(true_fourier) * 100
          abs_diff = abs(np.array(pred_fourier) - np.array(true_fourier))

          for idx, freq in enumerate(pred_freq):
            pct_dict["iter"].append(iter)
            pct_dict['freq'].append(freq)
            pct_dict['value'].append(pct_diff[idx])

            error_dict["iter"].append(iter)
            error_dict['freq'].append(freq)
            error_dict['value'].append(abs_diff[idx])


    pct_diffs = pd.DataFrame(data = pct_dict)
    pct_diffs = pct_diffs.round(3)
    pct_diffs = pct_diffs.pivot("iter", "freq", "value")
    sns.heatmap(pct_diffs, yticklabels=20, xticklabels=10, vmin=0., vmax=100, cbar_kws={'label': 'Percentage Error in Amplitude'}, ax=ax0, cmap="BuPu")
    ax0.invert_yaxis()
    ax0.set_xlabel("Frequency")
    ax0.set_ylabel("Training Iteration")
    ax0.set_title(f"Frequency Dynamics of Predicted Solution at t = {t}")


    abs_diffs = pd.DataFrame(data = error_dict)
    abs_diffs = abs_diffs.round(3)
    abs_diffs = abs_diffs.pivot("iter", "freq", "value")
    sns.heatmap(abs_diffs, yticklabels=20, xticklabels=10, vmin=0., vmax=max(error_dict['value']), cbar_kws={'label': 'Absolute Error in Amplitude'}, ax=ax1, cmap="BuPu")
    ax1.invert_yaxis()
    ax1.set_xlabel("Frequency")
    ax1.set_ylabel("Training Iteration")
    ax1.set_title(f"Frequency Dynamics of Predicted Solution at t = {t}")

    plt.show()

# %%
def plot_l2_errors(preds, y_true, iteration, domain_len):
    fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(20, 8))

    freq_dict = {"time": [], "freq": [], "value": []}
    x_dict = {"time": [], "x": [], "value": []}

    for t in np.linspace(0, 0.99, 100):
      start = int(256 * t * 100)
      end = start + 256
      xs = X[:, 0][start:end]
      true_freq, true_fourier = get_fft(y_true[start:end], 256/domain_len)
      pred_freq, pred_fourier = get_fft(preds[start:end], 256/domain_len)
      freq_diff = abs(np.array(pred_fourier) - np.array(true_fourier))

      true_sol = y_true[start:end]
      pred_sol = preds[start:end]
      abs_diff = abs(np.array(pred_sol) - np.array(true_sol))[0]

      for idx, freq in enumerate(pred_freq):
        freq_dict["time"].append(t)
        freq_dict['freq'].append(freq)
        freq_dict['value'].append((freq_diff[idx] ** 2))

      for idx, _ in enumerate(pred_sol):
        if idx != 255:
          x_dict["time"].append(t)
          x_dict['x'].append(xs[idx])
          x_dict['value'].append((abs_diff[idx] ** 2))

    freq_errors = pd.DataFrame(data = freq_dict)
    freq_errors = freq_errors.round(3)
    freq_errors = freq_errors.pivot("time", "freq", "value")
    sns.heatmap(freq_errors, yticklabels=3, xticklabels=10, vmin=0, norm=LogNorm(), cbar_kws={'label': 'L2 Error of Prediction'}, ax=ax0, cmap="BuPu")
    ax0.invert_yaxis()
    ax0.set_xlabel("Frequency")
    ax0.set_ylabel("Time")
    ax0.set_title(f"Decomposing L2 Error of Predicted Solution at Iteration {iteration}")

    l2_errors = pd.DataFrame(data = x_dict)
    l2_errors = l2_errors.round(3)
    l2_errors = l2_errors.pivot("time", "x", "value")
    sns.heatmap(l2_errors, yticklabels=3, xticklabels=10, vmin=0, norm=LogNorm(), cbar_kws={'label': 'L2 Error of Prediction'}, ax=ax1, cmap="BuPu")
    ax1.invert_yaxis()
    ax1.set_xlabel("x")
    ax1.set_ylabel("t")
    ax1.set_title(f"Decomposing L2 Error of Predicted Solution at Iteration {iteration}")

    plt.show()

# %% [markdown]
# ### Visualizations

# %%
import pickle

# compare the true solution with the predicted solution
X, y_true = gen_testdata()

with open('long_model_preds_diffusion.pkl', 'rb') as f:
    all_preds = pickle.load(f)

# %%
plot_spectral_dynamics(all_preds, y_true, 0.00, domain_len=2)
plot_spectral_dynamics(all_preds, y_true, 0.25, domain_len=2)
plot_spectral_dynamics(all_preds, y_true, 0.50, domain_len=2)
plot_spectral_dynamics(all_preds, y_true, 0.75, domain_len=2)
plot_spectral_dynamics(all_preds, y_true, 0.99, domain_len=2)
# Out:
# <ipython-input-11-92b004ec8a7c>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:33: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pct_diffs = pct_diffs.pivot("iter", "freq", "value")
# <ipython-input-11-92b004ec8a7c>:43: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   abs_diffs = abs_diffs.pivot("iter", "freq", "value")

# %%
compare_solutions(0, y_true, all_preds[500000], domain_len=2)
compare_solutions(0.25, y_true, all_preds[500000], domain_len=2)
compare_solutions(0.5, y_true, all_preds[500000], domain_len=2)
compare_solutions(0.75, y_true, all_preds[500000], domain_len=2)
compare_solutions(0.99, y_true, all_preds[500000], domain_len=2)

# %%
plot_l2_errors(all_preds[100000], y_true, 100000, domain_len=2)
plot_l2_errors(all_preds[200000], y_true, 200000, domain_len=2)
plot_l2_errors(all_preds[300000], y_true, 300000, domain_len=2)
plot_l2_errors(all_preds[400000], y_true, 400000, domain_len=2)
plot_l2_errors(all_preds[500000], y_true, 500000, domain_len=2)
# Out:
# <ipython-input-12-70d171eeefca>:32: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   freq_errors = freq_errors.pivot("time", "freq", "value")
# <ipython-input-12-70d171eeefca>:41: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   l2_errors = l2_errors.pivot("time", "x", "value")
# <ipython-input-12-70d171eeefca>:32: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   freq_errors = freq_errors.pivot("time", "freq", "value")
# <ipython-input-12-70d171eeefca>:41: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   l2_errors = l2_errors.pivot("time", "x", "value")
# <ipython-input-12-70d171eeefca>:32: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   freq_errors = freq_errors.pivot("time", "freq", "value")
# <ipython-input-12-70d171eeefca>:41: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   l2_errors = l2_errors.pivot("time", "x", "value")
# <ipython-input-12-70d171eeefca>:32: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   freq_errors = freq_errors.pivot("time", "freq", "value")
# <ipython-input-12-70d171eeefca>:41: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   l2_errors = l2_errors.pivot("time", "x", "value")
# <ipython-input-12-70d171eeefca>:32: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   freq_errors = freq_errors.pivot("time", "freq", "value")
# <ipython-input-12-70d171eeefca>:41: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   l2_errors = l2_errors.pivot("time", "x", "value")

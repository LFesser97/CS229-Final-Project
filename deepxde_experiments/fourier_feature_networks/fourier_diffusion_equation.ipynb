# %%
"""
fourier_diffusion_equation.ipynb

Created on Sat Apr 15 2023

@author: Luca d'Amico-Wong, Lukas Fesser, Richard Qiu

This file contains code to train a PINN with (random) Fourier feature
mappings to solve the Diffusion Equation from this DeepXDE demo:
https://deepxde.readthedocs.io/en/latest/demos/pinn_forward/diffusion.1d.html
"""
# Out:
# '\nfourier_diffusion_equation.ipynb\n\nCreated on Sat Apr 15 2023\n\n@author: Lukas\n\nThis file contains code to train a PINN with (random) Fourier feature\nmappings to solve the Diffusion Equation from this DeepXDE demo:\nhttps://deepxde.readthedocs.io/en/latest/demos/pinn_forward/diffusion.1d.html\n'

# %% [markdown]
# In this notebook, we solve the diffusion equation
# $$\frac{\delta y}{\delta t} = \frac{\delta^2 y}{\delta x^2} - e^{-t} \left( \sin (\pi x) - \pi^2 \sin (\pi x) \right) $$
#
# for $x in [-1, 1]$ and $t \in [0, 1]$ with the initial condition $y(x, 0) = \sin (\pi x)$ and the Dirichlet boundary condition $y(-1, t) = y(1, t) = 0$. The reference solution is $y = e^{-t} \sin (\pi x)$. We use $t \in [0, 0.5]$ as the temporal training domain and consider $t \in (0.5, 1]$ as the extrapolation area.

# %%
# install DeepXDE

# %pip install deepxde
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepxde
#   Downloading DeepXDE-1.8.4-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 889.4 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from deepxde) (3.7.1)
# Collecting scikit-optimize>=0.9.0
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.22.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.2.0)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->deepxde) (3.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->deepxde) (3.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)
# Installing collected packages: pyaml, scikit-optimize, deepxde
# Successfully installed deepxde-1.8.4 pyaml-21.10.1 scikit-optimize-0.9.0

# %%
# import packages

import deepxde as dde
import numpy as np

from deepxde.backend import tf

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
import random
# Out:
# No backend selected.
# Finding available backend...
# Using backend: tensorflow.compat.v1
# Other supported backends: tensorflow, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Found tensorflow.compat.v1
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)
# Enable just-in-time compilation with XLA.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.

# %%
# set up the problem

def pde(x, y):
    dy_t = dde.grad.jacobian(y, x, j=1)
    dy_xx = dde.grad.hessian(y, x, j=0)
    return (
        dy_t
        - dy_xx
        + tf.exp(-x[:, 1:])
        * (tf.sin(np.pi * x[:, 0:1]) - np.pi ** 2 * tf.sin(np.pi * x[:, 0:1]))
    )

def func(x):
    return np.sin(np.pi * x[:, 0:1]) * np.exp(-x[:, 1:])


geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0, 0.5)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

bc = dde.icbc.DirichletBC(geomtime, func, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(geomtime, func, lambda _, on_initial: on_initial)
data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc, ic],
    num_domain=40,
    num_boundary=20,
    num_initial=10,
    solution=func,
    num_test=10000,
)

# %%
# set up the model

layer_size = [2] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.MsFFN(layer_size, activation, initializer, sigmas=[0.5])

model = dde.Model(data, net)

model.compile("adam", lr=0.001, metrics=["l2 relative error"])
# Out:
# Compiling model...
# Building Multiscale Fourier Feature Network...
# /usr/local/lib/python3.9/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:114: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'compile' took 3.268465 s

# %%
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...

# %%
zero_predictions = []
half_predictions = []
one_predictions = []

# %%
# predict the solution at t = 0 for x in [-1, 1]

for i in range(10):
    model.train(iterations=5000)

    x = geom.uniform_points(256, True)
    t = np.zeros((256, 1))
    x = np.concatenate([x, t], 1)
    y = model.predict(x)
    zero_predictions.append(y)

    x = geom.uniform_points(256, True)
    t = np.full(256, 0.5)
    x = np.hstack((x, t.reshape(-1, 1)))
    y = model.predict(x)
    half_predictions.append(y)

    x = geom.uniform_points(256, True)
    t = np.full(256, 1.0)
    x = np.hstack((x, t.reshape(-1, 1)))
    y = model.predict(x)
    one_predictions.append(y)
# Out:
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 50000     [7.91e-06, 1.13e-06, 9.83e-07]    [2.56e-05, 1.13e-06, 9.83e-07]    [1.55e-03]
# 51000     [8.60e-06, 2.78e-07, 7.61e-07]    [2.44e-05, 2.78e-07, 7.61e-07]    [8.65e-04]
# 52000     [1.17e-05, 1.06e-06, 8.95e-07]    [3.13e-05, 1.06e-06, 8.95e-07]    [1.52e-03]
# 53000     [6.19e-05, 5.31e-06, 5.64e-06]    [9.52e-05, 5.31e-06, 5.64e-06]    [4.17e-03]
# 54000     [3.40e-05, 4.41e-07, 1.20e-06]    [5.27e-05, 4.41e-07, 1.20e-06]    [1.39e-03]
# 55000     [1.29e-05, 3.36e-07, 8.15e-07]    [2.87e-05, 3.36e-07, 8.16e-07]    [9.92e-04]
#
# Best model at step 40000:
#   train loss: 4.59e-06
#   test loss: 1.93e-05
#   test metric: [1.21e-03]
#
# 'train' took 5.353594 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 55000     [1.29e-05, 3.36e-07, 8.15e-07]    [2.87e-05, 3.36e-07, 8.16e-07]    [9.92e-04]
# 56000     [8.65e-06, 2.91e-07, 7.36e-07]    [2.46e-05, 2.91e-07, 7.36e-07]    [9.53e-04]
# 57000     [6.58e-06, 1.31e-07, 5.29e-07]    [2.53e-05, 1.31e-07, 5.29e-07]    [6.91e-04]
# 58000     [3.25e-06, 1.02e-07, 3.32e-07]    [2.00e-05, 1.02e-07, 3.32e-07]    [3.78e-04]
# 59000     [5.36e-05, 8.91e-06, 7.40e-06]    [7.24e-05, 8.91e-06, 7.40e-06]    [5.08e-03]
# 60000     [5.75e-04, 1.94e-05, 6.98e-06]    [4.28e-04, 1.94e-05, 6.98e-06]    [4.82e-03]
#
# Best model at step 58000:
#   train loss: 3.69e-06
#   test loss: 2.05e-05
#   test metric: [3.78e-04]
#
# 'train' took 5.699179 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 60000     [5.75e-04, 1.94e-05, 6.98e-06]    [4.28e-04, 1.94e-05, 6.98e-06]    [4.82e-03]
# 61000     [3.85e-05, 2.52e-06, 1.84e-06]    [4.51e-05, 2.52e-06, 1.84e-06]    [2.31e-03]
# 62000     [8.04e-06, 5.07e-07, 4.86e-07]    [2.82e-05, 5.07e-07, 4.86e-07]    [9.13e-04]
# 63000     [2.95e-04, 8.20e-06, 4.91e-06]    [2.25e-04, 8.20e-06, 4.91e-06]    [3.67e-03]
# 64000     [4.30e-06, 9.44e-08, 3.10e-07]    [2.46e-05, 9.44e-08, 3.10e-07]    [3.60e-04]
# 65000     [2.83e-05, 2.99e-07, 1.82e-06]    [4.72e-05, 2.99e-07, 1.82e-06]    [2.01e-03]
#
# Best model at step 58000:
#   train loss: 3.69e-06
#   test loss: 2.05e-05
#   test metric: [3.78e-04]
#
# 'train' took 5.322314 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 65000     [2.83e-05, 2.99e-07, 1.82e-06]    [4.72e-05, 2.99e-07, 1.82e-06]    [2.01e-03]
# 66000     [5.44e-04, 1.38e-05, 6.43e-06]    [4.49e-04, 1.38e-05, 6.43e-06]    [4.70e-03]
# 67000     [3.46e-04, 7.57e-06, 3.17e-05]    [3.35e-04, 7.57e-06, 3.17e-05]    [8.46e-03]
# 68000     [3.16e-06, 3.38e-07, 4.56e-07]    [2.01e-05, 3.38e-07, 4.56e-07]    [8.94e-04]
# 69000     [5.62e-05, 3.87e-06, 3.37e-06]    [5.23e-05, 3.87e-06, 3.37e-06]    [3.18e-03]
# 70000     [1.01e-03, 2.18e-05, 1.20e-05]    [9.16e-04, 2.18e-05, 1.20e-05]    [5.94e-03]
#
# Best model at step 58000:
#   train loss: 3.69e-06
#   test loss: 2.05e-05
#   test metric: [3.78e-04]
#
# 'train' took 5.713152 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 70000     [1.01e-03, 2.18e-05, 1.20e-05]    [9.16e-04, 2.18e-05, 1.20e-05]    [5.94e-03]
# 71000     [5.16e-06, 7.04e-08, 2.96e-07]    [2.43e-05, 7.04e-08, 2.96e-07]    [4.99e-04]
# 72000     [5.87e-04, 9.22e-07, 1.12e-05]    [7.38e-04, 9.22e-07, 1.12e-05]    [5.66e-03]
# 73000     [1.28e-05, 1.08e-06, 1.15e-06]    [2.92e-05, 1.08e-06, 1.15e-06]    [1.71e-03]
# 74000     [3.25e-06, 3.07e-07, 8.22e-07]    [2.67e-05, 3.07e-07, 8.22e-07]    [1.21e-03]
# 75000     [2.45e-04, 7.07e-05, 1.01e-04]    [3.17e-04, 7.07e-05, 1.01e-04]    [1.71e-02]
#
# Best model at step 58000:
#   train loss: 3.69e-06
#   test loss: 2.05e-05
#   test metric: [3.78e-04]
#
# 'train' took 5.946800 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 75000     [2.45e-04, 7.07e-05, 1.01e-04]    [3.17e-04, 7.07e-05, 1.01e-04]    [1.71e-02]
# 76000     [2.46e-04, 1.47e-05, 6.37e-06]    [1.81e-04, 1.47e-05, 6.37e-06]    [5.21e-03]
# 77000     [6.25e-06, 1.07e-06, 7.52e-07]    [2.23e-05, 1.07e-06, 7.52e-07]    [1.44e-03]
# 78000     [6.24e-05, 1.38e-06, 8.97e-07]    [6.03e-05, 1.38e-06, 8.97e-07]    [1.48e-03]
# 79000     [2.53e-06, 2.26e-07, 2.69e-07]    [2.47e-05, 2.26e-07, 2.69e-07]    [8.57e-04]
# 80000     [7.78e-04, 2.15e-05, 7.19e-06]    [6.59e-04, 2.15e-05, 7.19e-06]    [4.75e-03]
#
# Best model at step 79000:
#   train loss: 3.03e-06
#   test loss: 2.52e-05
#   test metric: [8.57e-04]
#
# 'train' took 6.396899 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 80000     [7.78e-04, 2.15e-05, 7.19e-06]    [6.59e-04, 2.15e-05, 7.19e-06]    [4.75e-03]
# 81000     [2.03e-04, 1.42e-05, 4.35e-06]    [2.27e-04, 1.42e-05, 4.35e-06]    [4.18e-03]
# 82000     [1.21e-05, 3.07e-06, 1.21e-06]    [3.87e-05, 3.07e-06, 1.21e-06]    [2.36e-03]
# 83000     [1.47e-05, 4.79e-07, 6.97e-07]    [3.34e-05, 4.79e-07, 6.97e-07]    [1.37e-03]
# 84000     [3.20e-05, 9.60e-07, 2.50e-07]    [5.97e-05, 9.60e-07, 2.50e-07]    [1.01e-03]
# 85000     [4.96e-04, 1.67e-04, 1.81e-04]    [3.13e-04, 1.67e-04, 1.81e-04]    [2.51e-02]
#
# Best model at step 79000:
#   train loss: 3.03e-06
#   test loss: 2.52e-05
#   test metric: [8.57e-04]
#
# 'train' took 5.330176 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 85000     [4.96e-04, 1.67e-04, 1.81e-04]    [3.13e-04, 1.67e-04, 1.81e-04]    [2.51e-02]
# 86000     [3.68e-05, 1.64e-06, 9.99e-07]    [6.93e-05, 1.64e-06, 9.99e-07]    [1.98e-03]
# 87000     [2.33e-06, 1.32e-07, 1.31e-07]    [2.29e-05, 1.32e-07, 1.31e-07]    [5.10e-04]
# 88000     [3.33e-04, 1.11e-05, 2.48e-05]    [4.47e-04, 1.11e-05, 2.48e-05]    [7.71e-03]
# 89000     [4.15e-06, 1.99e-07, 2.41e-07]    [2.65e-05, 1.99e-07, 2.41e-07]    [8.62e-04]
# 90000     [7.72e-05, 1.85e-06, 4.14e-06]    [1.18e-04, 1.85e-06, 4.14e-06]    [3.09e-03]
#
# Best model at step 87000:
#   train loss: 2.59e-06
#   test loss: 2.32e-05
#   test metric: [5.10e-04]
#
# 'train' took 5.867063 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 90000     [7.72e-05, 1.85e-06, 4.14e-06]    [1.18e-04, 1.85e-06, 4.14e-06]    [3.09e-03]
# 91000     [6.21e-04, 1.76e-05, 9.52e-06]    [5.93e-04, 1.76e-05, 9.52e-06]    [5.38e-03]
# 92000     [5.95e-06, 1.40e-07, 1.63e-07]    [2.38e-05, 1.40e-07, 1.63e-07]    [5.83e-04]
# 93000     [1.12e-05, 2.11e-06, 7.81e-07]    [3.54e-05, 2.11e-06, 7.81e-07]    [1.90e-03]
# 94000     [9.17e-04, 2.49e-05, 8.50e-06]    [7.77e-04, 2.49e-05, 8.50e-06]    [5.51e-03]
# 95000     [2.27e-05, 1.12e-07, 6.56e-07]    [4.38e-05, 1.11e-07, 6.56e-07]    [1.22e-03]
#
# Best model at step 87000:
#   train loss: 2.59e-06
#   test loss: 2.32e-05
#   test metric: [5.10e-04]
#
# 'train' took 5.386544 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 95000     [2.27e-05, 1.12e-07, 6.56e-07]    [4.38e-05, 1.11e-07, 6.56e-07]    [1.22e-03]
# 96000     [1.76e-05, 2.05e-07, 5.90e-07]    [3.76e-05, 2.05e-07, 5.90e-07]    [8.11e-04]
# 97000     [9.48e-05, 9.60e-07, 2.49e-06]    [1.17e-04, 9.60e-07, 2.49e-06]    [2.14e-03]
# 98000     [2.07e-04, 3.80e-06, 2.35e-06]    [1.64e-04, 3.80e-06, 2.35e-06]    [2.50e-03]
# 99000     [1.36e-04, 8.73e-07, 4.69e-06]    [1.61e-04, 8.73e-07, 4.69e-06]    [3.03e-03]
# 100000    [1.99e-05, 8.47e-07, 2.76e-06]    [4.14e-05, 8.47e-07, 2.76e-06]    [2.66e-03]
#
# Best model at step 87000:
#   train loss: 2.59e-06
#   test loss: 2.32e-05
#   test metric: [5.10e-04]
#
# 'train' took 5.741242 s

# %%
# plot the solution and compare it to the sine function

for i in range(len(zero_predictions)):
    plt.plot(x[:, 0], zero_predictions[i][:, 0], label="PINN, " + str((i+1) * 5000))

plt.plot(x[:, 0], np.exp(0) * np.sin(np.pi * x[:, 0]), label="True Solution")
#plt.legend()
plt.title("Functions learned at t = 0")
plt.xlabel("x")
plt.ylabel("u(x, 0)")
plt.show()

# %%
# plot the solution

for i in range(len(half_predictions)):
    plt.plot(x[:, 0], half_predictions[i][:, 0], label="PINN, " + str((i+1) * 5000))

plt.plot(x[:, 0], np.exp(-0.5) * np.sin(np.pi * x[:, 0]), label="True Solution")
#plt.legend()
plt.title("Functions learned at t = 0.5")
plt.xlabel("x")
plt.ylabel("u(x, 0.5)")
plt.show()

# %%
# plot the solution

for i in range(len(one_predictions)):
    plt.plot(x[:, 0], one_predictions[i][:, 0], label= ("PINN, " + str((i+1) * 5000)))

plt.plot(x[:, 0], np.exp(-1) * np.sin(np.pi * x[:, 0]), label="True Solution")
plt.legend()
plt.title("Functions learned at t = 1")
plt.xlabel("x")
plt.ylabel("u(x, 1)")
plt.show()

# %%
# compute the L2 relative error between the true solution and the predicted solution

rel_l2_errors = []

for t in range(100):
    x = geom.uniform_points(256, True)
    t = np.full(256, t/100)
    x = np.hstack((x, t.reshape(-1, 1)))
    y_pred = model.predict(x)

    y_sol = func(x)

    # collect the relative L2 errors in a list
    rel_l2_errors.append(dde.metrics.l2_relative_error(y_sol, y_pred))


# plot the relative L2 errors

x = np.linspace(0, 1, 100)
plt.plot(x, rel_l2_errors)
plt.xlabel("t")
plt.ylabel("L2 relative error")
plt.show()

# %%
# compute the absolute residuals, i.e. the deviation from the PDE

absolute_residual = []

for t in range(100):
    x = geom.uniform_points(256, True)
    t = np.full(256, t/100)
    X = np.hstack((x, t.reshape(-1, 1)))

    f = model.predict(X, operator=pde)
    absolute_residual.append(np.mean(np.absolute(f)))


# plot the absolute residuals

x = np.linspace(0, 0.01 * 100, 100)
plt.plot(x, absolute_residual)
plt.xlabel("t")
plt.ylabel("Absolute Residual")
plt.show()

# %%
mean_residual_inter = []
mean_residual_extra = []

l2_error_inter = []
l2_error_extra = []

# %%
# set up the model

layer_size = [2] + [50] * 5 + [1]
activation = "sin"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

model = dde.Model(data, net)

model.compile("adam", lr=0.0001, metrics=["l2 relative error"])
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.084894 s
#
# 'compile' took 1.044982 s

# %%
# record mean residuals and l2-residuals over training epochs for t in [0, 1]

def create_data(t):
    x = geom.uniform_points(256, True)
    t = np.full(256, t/100)
    X = np.hstack((x, t.reshape(-1, 1)))
    return X

for i in range(100):
    model.train(iterations=1000)

    y_pred = np.array([model.predict(create_data(t)) for t in range(100)])
    y_sol = np.array([func(create_data(t)) for t in range(100)])
    # f = np.array([model.predict(create_data(t), operator=pde) for t in range(100)])

    # mean_residual_inter.append(np.mean(np.absolute(f)[:12800]))
    l2_error_inter.append(dde.metrics.l2_relative_error(y_sol[:50, :, :], y_pred[:50, :, :]))

    # mean_residual_extra.append(np.mean(np.absolute(f)[12800:]))
    l2_error_extra.append(dde.metrics.l2_relative_error(y_sol[50:, :, :], y_pred[50:, :, :]))
# Out:
# Initializing variables...
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [2.07e+01, 3.10e-02, 6.45e-01]    [2.52e+01, 3.10e-02, 6.45e-01]    [1.16e+00]
# 1000      [1.99e-02, 5.08e-03, 6.11e-04]    [2.30e-02, 5.08e-03, 6.11e-04]    [6.09e-02]
#
# Best model at step 1000:
#   train loss: 2.56e-02
#   test loss: 2.87e-02
#   test metric: [6.09e-02]
#
# 'train' took 6.103838 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 1000      [1.99e-02, 5.08e-03, 6.11e-04]    [2.30e-02, 5.08e-03, 6.11e-04]    [6.09e-02]
# 2000      [5.41e-03, 4.57e-03, 7.05e-04]    [6.99e-03, 4.57e-03, 7.05e-04]    [6.06e-02]
#
# Best model at step 2000:
#   train loss: 1.07e-02
#   test loss: 1.23e-02
#   test metric: [6.06e-02]
#
# 'train' took 2.846064 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 2000      [5.41e-03, 4.57e-03, 7.05e-04]    [6.99e-03, 4.57e-03, 7.05e-04]    [6.06e-02]
# 3000      [2.53e-03, 1.89e-03, 3.51e-04]    [3.30e-03, 1.89e-03, 3.51e-04]    [3.86e-02]
#
# Best model at step 3000:
#   train loss: 4.78e-03
#   test loss: 5.54e-03
#   test metric: [3.86e-02]
#
# 'train' took 3.083781 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 3000      [2.53e-03, 1.89e-03, 3.51e-04]    [3.30e-03, 1.89e-03, 3.51e-04]    [3.86e-02]
# 4000      [8.90e-04, 4.01e-04, 2.07e-04]    [1.30e-03, 4.01e-04, 2.07e-04]    [1.67e-02]
#
# Best model at step 4000:
#   train loss: 1.50e-03
#   test loss: 1.90e-03
#   test metric: [1.67e-02]
#
# 'train' took 2.338789 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 4000      [8.90e-04, 4.01e-04, 2.07e-04]    [1.30e-03, 4.01e-04, 2.07e-04]    [1.67e-02]
# 5000      [5.65e-04, 1.56e-04, 1.35e-04]    [9.17e-04, 1.56e-04, 1.35e-04]    [1.04e-02]
#
# Best model at step 5000:
#   train loss: 8.56e-04
#   test loss: 1.21e-03
#   test metric: [1.04e-02]
#
# 'train' took 2.391408 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 5000      [5.65e-04, 1.56e-04, 1.35e-04]    [9.17e-04, 1.56e-04, 1.35e-04]    [1.04e-02]
# 6000      [3.81e-04, 7.33e-05, 8.65e-05]    [6.09e-04, 7.33e-05, 8.65e-05]    [7.27e-03]
#
# Best model at step 6000:
#   train loss: 5.40e-04
#   test loss: 7.69e-04
#   test metric: [7.27e-03]
#
# 'train' took 2.365950 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 6000      [3.81e-04, 7.33e-05, 8.65e-05]    [6.09e-04, 7.33e-05, 8.65e-05]    [7.27e-03]
# 7000      [2.59e-04, 3.54e-05, 5.41e-05]    [4.03e-04, 3.54e-05, 5.41e-05]    [5.17e-03]
#
# Best model at step 7000:
#   train loss: 3.48e-04
#   test loss: 4.93e-04
#   test metric: [5.17e-03]
#
# 'train' took 2.671435 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 7000      [2.59e-04, 3.54e-05, 5.41e-05]    [4.03e-04, 3.54e-05, 5.41e-05]    [5.17e-03]
# 8000      [1.79e-04, 1.87e-05, 3.51e-05]    [2.73e-04, 1.87e-05, 3.51e-05]    [3.76e-03]
#
# Best model at step 8000:
#   train loss: 2.32e-04
#   test loss: 3.27e-04
#   test metric: [3.76e-03]
#
# 'train' took 3.005210 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 8000      [1.79e-04, 1.87e-05, 3.51e-05]    [2.73e-04, 1.87e-05, 3.51e-05]    [3.76e-03]
# 9000      [1.19e-04, 1.13e-05, 2.37e-05]    [1.81e-04, 1.13e-05, 2.37e-05]    [3.07e-03]
#
# Best model at step 9000:
#   train loss: 1.54e-04
#   test loss: 2.16e-04
#   test metric: [3.07e-03]
#
# 'train' took 2.548185 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 9000      [1.19e-04, 1.13e-05, 2.37e-05]    [1.81e-04, 1.13e-05, 2.37e-05]    [3.07e-03]
# 10000     [2.39e-04, 2.37e-05, 2.03e-05]    [1.40e-04, 2.37e-05, 2.03e-05]    [4.01e-03]
#
# Best model at step 9000:
#   train loss: 1.54e-04
#   test loss: 2.16e-04
#   test metric: [3.07e-03]
#
# 'train' took 2.489468 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 10000     [2.39e-04, 2.37e-05, 2.03e-05]    [1.40e-04, 2.37e-05, 2.03e-05]    [4.01e-03]
# 11000     [5.00e-05, 7.87e-06, 1.27e-05]    [7.46e-05, 7.87e-06, 1.27e-05]    [2.54e-03]
#
# Best model at step 11000:
#   train loss: 7.06e-05
#   test loss: 9.52e-05
#   test metric: [2.54e-03]
#
# 'train' took 2.533782 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 11000     [5.00e-05, 7.87e-06, 1.27e-05]    [7.46e-05, 7.87e-06, 1.27e-05]    [2.54e-03]
# 12000     [8.43e-05, 1.07e-05, 9.76e-06]    [9.35e-05, 1.07e-05, 9.76e-06]    [3.11e-03]
#
# Best model at step 11000:
#   train loss: 7.06e-05
#   test loss: 9.52e-05
#   test metric: [2.54e-03]
#
# 'train' took 3.215247 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 12000     [8.43e-05, 1.07e-05, 9.76e-06]    [9.35e-05, 1.07e-05, 9.76e-06]    [3.11e-03]
# 13000     [2.50e-05, 7.47e-06, 8.49e-06]    [3.81e-05, 7.47e-06, 8.49e-06]    [2.40e-03]
#
# Best model at step 13000:
#   train loss: 4.09e-05
#   test loss: 5.41e-05
#   test metric: [2.40e-03]
#
# 'train' took 2.531315 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 13000     [2.50e-05, 7.47e-06, 8.49e-06]    [3.81e-05, 7.47e-06, 8.49e-06]    [2.40e-03]
# 14000     [2.05e-05, 7.23e-06, 7.25e-06]    [3.25e-05, 7.23e-06, 7.25e-06]    [2.34e-03]
#
# Best model at step 14000:
#   train loss: 3.49e-05
#   test loss: 4.70e-05
#   test metric: [2.34e-03]
#
# 'train' took 2.614432 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 14000     [2.05e-05, 7.23e-06, 7.25e-06]    [3.25e-05, 7.23e-06, 7.25e-06]    [2.34e-03]
# 15000     [1.80e-05, 6.88e-06, 6.49e-06]    [2.85e-05, 6.88e-06, 6.49e-06]    [2.24e-03]
#
# Best model at step 15000:
#   train loss: 3.14e-05
#   test loss: 4.18e-05
#   test metric: [2.24e-03]
#
# 'train' took 3.695720 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 15000     [1.80e-05, 6.88e-06, 6.49e-06]    [2.85e-05, 6.88e-06, 6.49e-06]    [2.24e-03]
# 16000     [2.70e-05, 7.45e-06, 5.21e-06]    [3.43e-05, 7.45e-06, 5.21e-06]    [2.37e-03]
#
# Best model at step 15000:
#   train loss: 3.14e-05
#   test loss: 4.18e-05
#   test metric: [2.24e-03]
#
# 'train' took 3.647632 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 16000     [2.70e-05, 7.45e-06, 5.21e-06]    [3.43e-05, 7.45e-06, 5.21e-06]    [2.37e-03]
# 17000     [1.55e-05, 5.95e-06, 5.38e-06]    [2.45e-05, 5.95e-06, 5.38e-06]    [2.06e-03]
#
# Best model at step 17000:
#   train loss: 2.68e-05
#   test loss: 3.58e-05
#   test metric: [2.06e-03]
#
# 'train' took 3.020545 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 17000     [1.55e-05, 5.95e-06, 5.38e-06]    [2.45e-05, 5.95e-06, 5.38e-06]    [2.06e-03]
# 18000     [1.71e-05, 5.52e-06, 5.27e-06]    [2.35e-05, 5.52e-06, 5.27e-06]    [1.97e-03]
#
# Best model at step 17000:
#   train loss: 2.68e-05
#   test loss: 3.58e-05
#   test metric: [2.06e-03]
#
# 'train' took 2.966006 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 18000     [1.71e-05, 5.52e-06, 5.27e-06]    [2.35e-05, 5.52e-06, 5.27e-06]    [1.97e-03]
# 19000     [1.38e-05, 5.04e-06, 4.53e-06]    [2.20e-05, 5.04e-06, 4.53e-06]    [1.88e-03]
#
# Best model at step 19000:
#   train loss: 2.34e-05
#   test loss: 3.16e-05
#   test metric: [1.88e-03]
#
# 'train' took 3.171192 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 19000     [1.38e-05, 5.04e-06, 4.53e-06]    [2.20e-05, 5.04e-06, 4.53e-06]    [1.88e-03]
# 20000     [1.30e-05, 4.69e-06, 4.08e-06]    [2.09e-05, 4.69e-06, 4.08e-06]    [1.80e-03]
#
# Best model at step 20000:
#   train loss: 2.18e-05
#   test loss: 2.96e-05
#   test metric: [1.80e-03]
#
# 'train' took 3.460463 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 20000     [1.30e-05, 4.69e-06, 4.08e-06]    [2.09e-05, 4.69e-06, 4.08e-06]    [1.80e-03]
# 21000     [1.53e-04, 1.47e-05, 3.91e-06]    [9.49e-05, 1.47e-05, 3.91e-06]    [3.55e-03]
#
# Best model at step 20000:
#   train loss: 2.18e-05
#   test loss: 2.96e-05
#   test metric: [1.80e-03]
#
# 'train' took 2.971232 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 21000     [1.53e-04, 1.47e-05, 3.91e-06]    [9.49e-05, 1.47e-05, 3.91e-06]    [3.55e-03]
# 22000     [1.84e-05, 4.20e-06, 4.15e-06]    [2.05e-05, 4.20e-06, 4.15e-06]    [1.64e-03]
#
# Best model at step 20000:
#   train loss: 2.18e-05
#   test loss: 2.96e-05
#   test metric: [1.80e-03]
#
# 'train' took 2.973154 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 22000     [1.84e-05, 4.20e-06, 4.15e-06]    [2.05e-05, 4.20e-06, 4.15e-06]    [1.64e-03]
# 23000     [1.14e-05, 3.64e-06, 3.27e-06]    [1.81e-05, 3.64e-06, 3.27e-06]    [1.56e-03]
#
# Best model at step 23000:
#   train loss: 1.83e-05
#   test loss: 2.50e-05
#   test metric: [1.56e-03]
#
# 'train' took 3.255274 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 23000     [1.14e-05, 3.64e-06, 3.27e-06]    [1.81e-05, 3.64e-06, 3.27e-06]    [1.56e-03]
# 24000     [1.10e-04, 8.76e-06, 7.02e-06]    [5.98e-05, 8.76e-06, 7.02e-06]    [2.62e-03]
#
# Best model at step 23000:
#   train loss: 1.83e-05
#   test loss: 2.50e-05
#   test metric: [1.56e-03]
#
# 'train' took 3.178817 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 24000     [1.10e-04, 8.76e-06, 7.02e-06]    [5.98e-05, 8.76e-06, 7.02e-06]    [2.62e-03]
# 25000     [1.06e-05, 3.13e-06, 2.83e-06]    [1.67e-05, 3.13e-06, 2.83e-06]    [1.43e-03]
#
# Best model at step 25000:
#   train loss: 1.66e-05
#   test loss: 2.27e-05
#   test metric: [1.43e-03]
#
# 'train' took 3.009020 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 25000     [1.06e-05, 3.13e-06, 2.83e-06]    [1.67e-05, 3.13e-06, 2.83e-06]    [1.43e-03]
# 26000     [1.10e-05, 2.97e-06, 2.56e-06]    [1.68e-05, 2.97e-06, 2.56e-06]    [1.42e-03]
#
# Best model at step 26000:
#   train loss: 1.65e-05
#   test loss: 2.23e-05
#   test metric: [1.42e-03]
#
# 'train' took 2.987510 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 26000     [1.10e-05, 2.97e-06, 2.56e-06]    [1.68e-05, 2.97e-06, 2.56e-06]    [1.42e-03]
# 27000     [1.03e-05, 2.67e-06, 2.48e-06]    [1.62e-05, 2.67e-06, 2.48e-06]    [1.35e-03]
#
# Best model at step 27000:
#   train loss: 1.55e-05
#   test loss: 2.14e-05
#   test metric: [1.35e-03]
#
# 'train' took 3.519486 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 27000     [1.03e-05, 2.67e-06, 2.48e-06]    [1.62e-05, 2.67e-06, 2.48e-06]    [1.35e-03]
# 28000     [1.13e-05, 2.38e-06, 2.58e-06]    [1.65e-05, 2.38e-06, 2.58e-06]    [1.27e-03]
#
# Best model at step 27000:
#   train loss: 1.55e-05
#   test loss: 2.14e-05
#   test metric: [1.35e-03]
#
# 'train' took 3.205437 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 28000     [1.13e-05, 2.38e-06, 2.58e-06]    [1.65e-05, 2.38e-06, 2.58e-06]    [1.27e-03]
# 29000     [9.36e-06, 2.31e-06, 2.19e-06]    [1.48e-05, 2.31e-06, 2.19e-06]    [1.23e-03]
#
# Best model at step 29000:
#   train loss: 1.39e-05
#   test loss: 1.93e-05
#   test metric: [1.23e-03]
#
# 'train' took 2.990371 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 29000     [9.36e-06, 2.31e-06, 2.19e-06]    [1.48e-05, 2.31e-06, 2.19e-06]    [1.23e-03]
# 30000     [9.05e-06, 2.09e-06, 2.20e-06]    [1.41e-05, 2.09e-06, 2.20e-06]    [1.14e-03]
#
# Best model at step 30000:
#   train loss: 1.33e-05
#   test loss: 1.84e-05
#   test metric: [1.14e-03]
#
# 'train' took 3.015969 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 30000     [9.05e-06, 2.09e-06, 2.20e-06]    [1.41e-05, 2.09e-06, 2.20e-06]    [1.14e-03]
# 31000     [4.04e-05, 3.74e-06, 3.50e-06]    [2.62e-05, 3.74e-06, 3.50e-06]    [1.58e-03]
#
# Best model at step 30000:
#   train loss: 1.33e-05
#   test loss: 1.84e-05
#   test metric: [1.14e-03]
#
# 'train' took 3.782387 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 31000     [4.04e-05, 3.74e-06, 3.50e-06]    [2.62e-05, 3.74e-06, 3.50e-06]    [1.58e-03]
# 32000     [8.41e-06, 1.86e-06, 1.90e-06]    [1.34e-05, 1.86e-06, 1.90e-06]    [1.08e-03]
#
# Best model at step 32000:
#   train loss: 1.22e-05
#   test loss: 1.72e-05
#   test metric: [1.08e-03]
#
# 'train' took 2.990729 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 32000     [8.41e-06, 1.86e-06, 1.90e-06]    [1.34e-05, 1.86e-06, 1.90e-06]    [1.08e-03]
# 33000     [1.29e-05, 2.00e-06, 1.70e-06]    [1.72e-05, 2.00e-06, 1.70e-06]    [1.24e-03]
#
# Best model at step 32000:
#   train loss: 1.22e-05
#   test loss: 1.72e-05
#   test metric: [1.08e-03]
#
# 'train' took 3.052678 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 33000     [1.29e-05, 2.00e-06, 1.70e-06]    [1.72e-05, 2.00e-06, 1.70e-06]    [1.24e-03]
# 34000     [3.15e-05, 3.01e-06, 2.58e-06]    [2.30e-05, 3.01e-06, 2.58e-06]    [1.34e-03]
#
# Best model at step 32000:
#   train loss: 1.22e-05
#   test loss: 1.72e-05
#   test metric: [1.08e-03]
#
# 'train' took 3.279465 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 34000     [3.15e-05, 3.01e-06, 2.58e-06]    [2.30e-05, 3.01e-06, 2.58e-06]    [1.34e-03]
# 35000     [8.28e-06, 1.61e-06, 1.60e-06]    [1.28e-05, 1.61e-06, 1.60e-06]    [9.99e-04]
#
# Best model at step 35000:
#   train loss: 1.15e-05
#   test loss: 1.60e-05
#   test metric: [9.99e-04]
#
# 'train' took 3.451541 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 35000     [8.28e-06, 1.61e-06, 1.60e-06]    [1.28e-05, 1.61e-06, 1.60e-06]    [9.99e-04]
# 36000     [3.44e-04, 1.48e-05, 3.71e-06]    [2.75e-04, 1.48e-05, 3.71e-06]    [3.98e-03]
#
# Best model at step 35000:
#   train loss: 1.15e-05
#   test loss: 1.60e-05
#   test metric: [9.99e-04]
#
# 'train' took 3.095090 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 36000     [3.44e-04, 1.48e-05, 3.71e-06]    [2.75e-04, 1.48e-05, 3.71e-06]    [3.98e-03]
# 37000     [7.55e-06, 1.41e-06, 1.48e-06]    [1.22e-05, 1.41e-06, 1.48e-06]    [9.47e-04]
#
# Best model at step 37000:
#   train loss: 1.04e-05
#   test loss: 1.51e-05
#   test metric: [9.47e-04]
#
# 'train' took 3.152373 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 37000     [7.55e-06, 1.41e-06, 1.48e-06]    [1.22e-05, 1.41e-06, 1.48e-06]    [9.47e-04]
# 38000     [1.90e-05, 2.10e-06, 1.26e-06]    [1.98e-05, 2.10e-06, 1.26e-06]    [1.30e-03]
#
# Best model at step 37000:
#   train loss: 1.04e-05
#   test loss: 1.51e-05
#   test metric: [9.47e-04]
#
# 'train' took 3.686105 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 38000     [1.90e-05, 2.10e-06, 1.26e-06]    [1.98e-05, 2.10e-06, 1.26e-06]    [1.30e-03]
# 39000     [8.13e-06, 1.22e-06, 1.43e-06]    [1.27e-05, 1.22e-06, 1.43e-06]    [9.11e-04]
#
# Best model at step 37000:
#   train loss: 1.04e-05
#   test loss: 1.51e-05
#   test metric: [9.47e-04]
#
# 'train' took 3.091900 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 39000     [8.13e-06, 1.22e-06, 1.43e-06]    [1.27e-05, 1.22e-06, 1.43e-06]    [9.11e-04]
# 40000     [7.08e-06, 1.19e-06, 1.32e-06]    [1.15e-05, 1.19e-06, 1.32e-06]    [8.65e-04]
#
# Best model at step 40000:
#   train loss: 9.59e-06
#   test loss: 1.40e-05
#   test metric: [8.65e-04]
#
# 'train' took 3.147549 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 40000     [7.08e-06, 1.19e-06, 1.32e-06]    [1.15e-05, 1.19e-06, 1.32e-06]    [8.65e-04]
# 41000     [6.98e-06, 1.15e-06, 1.28e-06]    [1.12e-05, 1.15e-06, 1.28e-06]    [8.38e-04]
#
# Best model at step 41000:
#   train loss: 9.42e-06
#   test loss: 1.36e-05
#   test metric: [8.38e-04]
#
# 'train' took 3.183881 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 41000     [6.98e-06, 1.15e-06, 1.28e-06]    [1.12e-05, 1.15e-06, 1.28e-06]    [8.38e-04]
# 42000     [8.40e-06, 1.07e-06, 1.37e-06]    [1.25e-05, 1.07e-06, 1.37e-06]    [8.55e-04]
#
# Best model at step 41000:
#   train loss: 9.42e-06
#   test loss: 1.36e-05
#   test metric: [8.38e-04]
#
# 'train' took 3.895392 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 42000     [8.40e-06, 1.07e-06, 1.37e-06]    [1.25e-05, 1.07e-06, 1.37e-06]    [8.55e-04]
# 43000     [2.52e-05, 1.98e-06, 1.35e-06]    [2.29e-05, 1.98e-06, 1.35e-06]    [1.17e-03]
#
# Best model at step 41000:
#   train loss: 9.42e-06
#   test loss: 1.36e-05
#   test metric: [8.38e-04]
#
# 'train' took 3.172878 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 43000     [2.52e-05, 1.98e-06, 1.35e-06]    [2.29e-05, 1.98e-06, 1.35e-06]    [1.17e-03]
# 44000     [6.62e-06, 1.03e-06, 1.11e-06]    [1.09e-05, 1.03e-06, 1.11e-06]    [8.25e-04]
#
# Best model at step 44000:
#   train loss: 8.76e-06
#   test loss: 1.30e-05
#   test metric: [8.25e-04]
#
# 'train' took 3.194123 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 44000     [6.62e-06, 1.03e-06, 1.11e-06]    [1.09e-05, 1.03e-06, 1.11e-06]    [8.25e-04]
# 45000     [9.49e-06, 1.18e-06, 1.08e-06]    [1.24e-05, 1.18e-06, 1.08e-06]    [8.67e-04]
#
# Best model at step 44000:
#   train loss: 8.76e-06
#   test loss: 1.30e-05
#   test metric: [8.25e-04]
#
# 'train' took 3.642824 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 45000     [9.49e-06, 1.18e-06, 1.08e-06]    [1.24e-05, 1.18e-06, 1.08e-06]    [8.67e-04]
# 46000     [2.60e-05, 2.12e-06, 1.75e-06]    [1.84e-05, 2.12e-06, 1.75e-06]    [1.14e-03]
#
# Best model at step 44000:
#   train loss: 8.76e-06
#   test loss: 1.30e-05
#   test metric: [8.25e-04]
#
# 'train' took 3.241479 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 46000     [2.60e-05, 2.12e-06, 1.75e-06]    [1.84e-05, 2.12e-06, 1.75e-06]    [1.14e-03]
# 47000     [6.25e-06, 9.32e-07, 1.02e-06]    [1.03e-05, 9.32e-07, 1.02e-06]    [7.84e-04]
#
# Best model at step 47000:
#   train loss: 8.20e-06
#   test loss: 1.23e-05
#   test metric: [7.84e-04]
#
# 'train' took 3.221332 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 47000     [6.25e-06, 9.32e-07, 1.02e-06]    [1.03e-05, 9.32e-07, 1.02e-06]    [7.84e-04]
# 48000     [7.18e-06, 9.58e-07, 9.54e-07]    [1.13e-05, 9.58e-07, 9.54e-07]    [8.53e-04]
#
# Best model at step 47000:
#   train loss: 8.20e-06
#   test loss: 1.23e-05
#   test metric: [7.84e-04]
#
# 'train' took 3.217848 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 48000     [7.18e-06, 9.58e-07, 9.54e-07]    [1.13e-05, 9.58e-07, 9.54e-07]    [8.53e-04]
# 49000     [6.08e-06, 8.73e-07, 9.68e-07]    [1.01e-05, 8.73e-07, 9.68e-07]    [7.70e-04]
#
# Best model at step 49000:
#   train loss: 7.92e-06
#   test loss: 1.19e-05
#   test metric: [7.70e-04]
#
# 'train' took 3.971421 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 49000     [6.08e-06, 8.73e-07, 9.68e-07]    [1.01e-05, 8.73e-07, 9.68e-07]    [7.70e-04]
# 50000     [3.77e-05, 2.61e-06, 2.19e-06]    [2.30e-05, 2.61e-06, 2.19e-06]    [1.37e-03]
#
# Best model at step 49000:
#   train loss: 7.92e-06
#   test loss: 1.19e-05
#   test metric: [7.70e-04]
#
# 'train' took 3.249893 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 50000     [3.77e-05, 2.61e-06, 2.19e-06]    [2.30e-05, 2.61e-06, 2.19e-06]    [1.37e-03]
# 51000     [1.18e-05, 1.30e-06, 7.96e-07]    [1.36e-05, 1.30e-06, 7.96e-07]    [1.07e-03]
#
# Best model at step 49000:
#   train loss: 7.92e-06
#   test loss: 1.19e-05
#   test metric: [7.70e-04]
#
# 'train' took 3.240717 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 51000     [1.18e-05, 1.30e-06, 7.96e-07]    [1.36e-05, 1.30e-06, 7.96e-07]    [1.07e-03]
# 52000     [5.83e-06, 8.27e-07, 8.96e-07]    [9.50e-06, 8.27e-07, 8.96e-07]    [7.46e-04]
#
# Best model at step 52000:
#   train loss: 7.55e-06
#   test loss: 1.12e-05
#   test metric: [7.46e-04]
#
# 'train' took 3.798451 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 52000     [5.83e-06, 8.27e-07, 8.96e-07]    [9.50e-06, 8.27e-07, 8.96e-07]    [7.46e-04]
# 53000     [5.83e-06, 8.28e-07, 8.51e-07]    [9.43e-06, 8.28e-07, 8.51e-07]    [7.55e-04]
#
# Best model at step 53000:
#   train loss: 7.51e-06
#   test loss: 1.11e-05
#   test metric: [7.55e-04]
#
# 'train' took 3.232553 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 53000     [5.83e-06, 8.28e-07, 8.51e-07]    [9.43e-06, 8.28e-07, 8.51e-07]    [7.55e-04]
# 54000     [5.63e-06, 7.91e-07, 8.55e-07]    [9.25e-06, 7.91e-07, 8.54e-07]    [7.41e-04]
#
# Best model at step 54000:
#   train loss: 7.28e-06
#   test loss: 1.09e-05
#   test metric: [7.41e-04]
#
# 'train' took 3.276898 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 54000     [5.63e-06, 7.91e-07, 8.55e-07]    [9.25e-06, 7.91e-07, 8.54e-07]    [7.41e-04]
# 55000     [7.24e-05, 4.36e-06, 1.41e-06]    [5.36e-05, 4.36e-06, 1.41e-06]    [2.25e-03]
#
# Best model at step 54000:
#   train loss: 7.28e-06
#   test loss: 1.09e-05
#   test metric: [7.41e-04]
#
# 'train' took 3.408021 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 55000     [7.24e-05, 4.36e-06, 1.41e-06]    [5.36e-05, 4.36e-06, 1.41e-06]    [2.25e-03]
# 56000     [5.48e-06, 7.69e-07, 7.97e-07]    [9.10e-06, 7.69e-07, 7.96e-07]    [7.47e-04]
#
# Best model at step 56000:
#   train loss: 7.04e-06
#   test loss: 1.07e-05
#   test metric: [7.47e-04]
#
# 'train' took 3.886116 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 56000     [5.48e-06, 7.69e-07, 7.97e-07]    [9.10e-06, 7.69e-07, 7.96e-07]    [7.47e-04]
# 57000     [8.54e-05, 5.78e-06, 2.90e-06]    [4.36e-05, 5.78e-06, 2.90e-06]    [2.09e-03]
#
# Best model at step 56000:
#   train loss: 7.04e-06
#   test loss: 1.07e-05
#   test metric: [7.47e-04]
#
# 'train' took 3.349803 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 57000     [8.54e-05, 5.78e-06, 2.90e-06]    [4.36e-05, 5.78e-06, 2.90e-06]    [2.09e-03]
# 58000     [7.81e-05, 3.69e-06, 1.20e-06]    [6.47e-05, 3.69e-06, 1.20e-06]    [1.96e-03]
#
# Best model at step 56000:
#   train loss: 7.04e-06
#   test loss: 1.07e-05
#   test metric: [7.47e-04]
#
# 'train' took 3.321506 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 58000     [7.81e-05, 3.69e-06, 1.20e-06]    [6.47e-05, 3.69e-06, 1.20e-06]    [1.96e-03]
# 59000     [7.44e-06, 9.20e-07, 6.71e-07]    [1.04e-05, 9.20e-07, 6.71e-07]    [8.95e-04]
#
# Best model at step 56000:
#   train loss: 7.04e-06
#   test loss: 1.07e-05
#   test metric: [7.47e-04]
#
# 'train' took 4.030376 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 59000     [7.44e-06, 9.20e-07, 6.71e-07]    [1.04e-05, 9.20e-07, 6.71e-07]    [8.95e-04]
# 60000     [1.60e-05, 1.26e-06, 8.34e-07]    [1.53e-05, 1.26e-06, 8.34e-07]    [9.89e-04]
#
# Best model at step 56000:
#   train loss: 7.04e-06
#   test loss: 1.07e-05
#   test metric: [7.47e-04]
#
# 'train' took 3.422739 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 60000     [1.60e-05, 1.26e-06, 8.34e-07]    [1.53e-05, 1.26e-06, 8.34e-07]    [9.89e-04]
# 61000     [5.47e-06, 7.22e-07, 7.86e-07]    [8.36e-06, 7.22e-07, 7.86e-07]    [7.08e-04]
#
# Best model at step 61000:
#   train loss: 6.98e-06
#   test loss: 9.87e-06
#   test metric: [7.08e-04]
#
# 'train' took 3.387275 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 61000     [5.47e-06, 7.22e-07, 7.86e-07]    [8.36e-06, 7.22e-07, 7.86e-07]    [7.08e-04]
# 62000     [6.00e-06, 6.86e-07, 7.98e-07]    [9.17e-06, 6.86e-07, 7.98e-07]    [7.24e-04]
#
# Best model at step 61000:
#   train loss: 6.98e-06
#   test loss: 9.87e-06
#   test metric: [7.08e-04]
#
# 'train' took 3.763822 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 62000     [6.00e-06, 6.86e-07, 7.98e-07]    [9.17e-06, 6.86e-07, 7.98e-07]    [7.24e-04]
# 63000     [5.23e-06, 7.25e-07, 7.07e-07]    [8.41e-06, 7.26e-07, 7.06e-07]    [7.47e-04]
#
# Best model at step 63000:
#   train loss: 6.67e-06
#   test loss: 9.85e-06
#   test metric: [7.47e-04]
#
# 'train' took 3.447860 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 63000     [5.23e-06, 7.25e-07, 7.07e-07]    [8.41e-06, 7.26e-07, 7.06e-07]    [7.47e-04]
# 64000     [5.48e-06, 7.46e-07, 6.71e-07]    [8.45e-06, 7.46e-07, 6.71e-07]    [7.64e-04]
#
# Best model at step 63000:
#   train loss: 6.67e-06
#   test loss: 9.85e-06
#   test metric: [7.47e-04]
#
# 'train' took 3.454050 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 64000     [5.48e-06, 7.46e-07, 6.71e-07]    [8.45e-06, 7.46e-07, 6.71e-07]    [7.64e-04]
# 65000     [4.85e-06, 6.90e-07, 6.70e-07]    [8.05e-06, 6.90e-07, 6.70e-07]    [7.32e-04]
#
# Best model at step 65000:
#   train loss: 6.21e-06
#   test loss: 9.41e-06
#   test metric: [7.32e-04]
#
# 'train' took 3.685140 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 65000     [4.85e-06, 6.90e-07, 6.70e-07]    [8.05e-06, 6.90e-07, 6.70e-07]    [7.32e-04]
# 66000     [4.89e-06, 7.02e-07, 6.44e-07]    [7.99e-06, 7.02e-07, 6.44e-07]    [7.46e-04]
#
# Best model at step 65000:
#   train loss: 6.21e-06
#   test loss: 9.41e-06
#   test metric: [7.32e-04]
#
# 'train' took 3.972677 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 66000     [4.89e-06, 7.02e-07, 6.44e-07]    [7.99e-06, 7.02e-07, 6.44e-07]    [7.46e-04]
# 67000     [4.73e-06, 6.81e-07, 6.50e-07]    [7.82e-06, 6.81e-07, 6.50e-07]    [7.30e-04]
#
# Best model at step 67000:
#   train loss: 6.06e-06
#   test loss: 9.15e-06
#   test metric: [7.30e-04]
#
# 'train' took 3.425154 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 67000     [4.73e-06, 6.81e-07, 6.50e-07]    [7.82e-06, 6.81e-07, 6.50e-07]    [7.30e-04]
# 68000     [3.78e-05, 2.67e-06, 1.65e-06]    [2.10e-05, 2.67e-06, 1.65e-06]    [1.39e-03]
#
# Best model at step 67000:
#   train loss: 6.06e-06
#   test loss: 9.15e-06
#   test metric: [7.30e-04]
#
# 'train' took 3.455438 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 68000     [3.78e-05, 2.67e-06, 1.65e-06]    [2.10e-05, 2.67e-06, 1.65e-06]    [1.39e-03]
# 69000     [8.57e-06, 1.01e-06, 5.61e-07]    [1.04e-05, 1.01e-06, 5.61e-07]    [9.90e-04]
#
# Best model at step 67000:
#   train loss: 6.06e-06
#   test loss: 9.15e-06
#   test metric: [7.30e-04]
#
# 'train' took 4.267446 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 69000     [8.57e-06, 1.01e-06, 5.61e-07]    [1.04e-05, 1.01e-06, 5.61e-07]    [9.90e-04]
# 70000     [4.62e-06, 6.53e-07, 6.36e-07]    [7.68e-06, 6.53e-07, 6.36e-07]    [7.24e-04]
#
# Best model at step 70000:
#   train loss: 5.91e-06
#   test loss: 8.97e-06
#   test metric: [7.24e-04]
#
# 'train' took 3.447455 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 70000     [4.62e-06, 6.53e-07, 6.36e-07]    [7.68e-06, 6.53e-07, 6.36e-07]    [7.24e-04]
# 71000     [5.14e-06, 6.46e-07, 6.50e-07]    [8.25e-06, 6.46e-07, 6.49e-07]    [7.36e-04]
#
# Best model at step 70000:
#   train loss: 5.91e-06
#   test loss: 8.97e-06
#   test metric: [7.24e-04]
#
# 'train' took 3.504699 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 71000     [5.14e-06, 6.46e-07, 6.50e-07]    [8.25e-06, 6.46e-07, 6.49e-07]    [7.36e-04]
# 72000     [1.43e-05, 1.40e-06, 5.37e-07]    [1.35e-05, 1.40e-06, 5.36e-07]    [1.17e-03]
#
# Best model at step 70000:
#   train loss: 5.91e-06
#   test loss: 8.97e-06
#   test metric: [7.24e-04]
#
# 'train' took 4.186585 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 72000     [1.43e-05, 1.40e-06, 5.37e-07]    [1.35e-05, 1.40e-06, 5.36e-07]    [1.17e-03]
# 73000     [4.49e-06, 6.53e-07, 5.93e-07]    [7.49e-06, 6.53e-07, 5.93e-07]    [7.37e-04]
#
# Best model at step 73000:
#   train loss: 5.74e-06
#   test loss: 8.74e-06
#   test metric: [7.37e-04]
#
# 'train' took 3.502450 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 73000     [4.49e-06, 6.53e-07, 5.93e-07]    [7.49e-06, 6.53e-07, 5.93e-07]    [7.37e-04]
# 74000     [5.19e-06, 6.73e-07, 6.85e-07]    [7.09e-06, 6.73e-07, 6.85e-07]    [7.04e-04]
#
# Best model at step 73000:
#   train loss: 5.74e-06
#   test loss: 8.74e-06
#   test metric: [7.37e-04]
#
# 'train' took 3.543607 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 74000     [5.19e-06, 6.73e-07, 6.85e-07]    [7.09e-06, 6.73e-07, 6.85e-07]    [7.04e-04]
# 75000     [4.52e-06, 6.44e-07, 6.26e-07]    [6.97e-06, 6.44e-07, 6.26e-07]    [7.06e-04]
#
# Best model at step 73000:
#   train loss: 5.74e-06
#   test loss: 8.74e-06
#   test metric: [7.37e-04]
#
# 'train' took 4.171352 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 75000     [4.52e-06, 6.44e-07, 6.26e-07]    [6.97e-06, 6.44e-07, 6.26e-07]    [7.06e-04]
# 76000     [1.09e-05, 1.07e-06, 7.50e-07]    [8.90e-06, 1.07e-06, 7.50e-07]    [9.31e-04]
#
# Best model at step 73000:
#   train loss: 5.74e-06
#   test loss: 8.74e-06
#   test metric: [7.37e-04]
#
# 'train' took 3.598960 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 76000     [1.09e-05, 1.07e-06, 7.50e-07]    [8.90e-06, 1.07e-06, 7.50e-07]    [9.31e-04]
# 77000     [4.80e-06, 6.98e-07, 5.30e-07]    [7.19e-06, 6.98e-07, 5.30e-07]    [7.68e-04]
#
# Best model at step 73000:
#   train loss: 5.74e-06
#   test loss: 8.74e-06
#   test metric: [7.37e-04]
#
# 'train' took 3.599468 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 77000     [4.80e-06, 6.98e-07, 5.30e-07]    [7.19e-06, 6.98e-07, 5.30e-07]    [7.68e-04]
# 78000     [5.59e-05, 3.61e-06, 2.21e-06]    [2.88e-05, 3.61e-06, 2.21e-06]    [1.70e-03]
#
# Best model at step 73000:
#   train loss: 5.74e-06
#   test loss: 8.74e-06
#   test metric: [7.37e-04]
#
# 'train' took 4.020792 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 78000     [5.59e-05, 3.61e-06, 2.21e-06]    [2.88e-05, 3.61e-06, 2.21e-06]    [1.70e-03]
# 79000     [4.78e-06, 6.27e-07, 5.99e-07]    [7.64e-06, 6.27e-07, 5.99e-07]    [7.42e-04]
#
# Best model at step 73000:
#   train loss: 5.74e-06
#   test loss: 8.74e-06
#   test metric: [7.37e-04]
#
# 'train' took 3.793653 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 79000     [4.78e-06, 6.27e-07, 5.99e-07]    [7.64e-06, 6.27e-07, 5.99e-07]    [7.42e-04]
# 80000     [4.10e-06, 6.27e-07, 5.54e-07]    [6.79e-06, 6.27e-07, 5.54e-07]    [7.27e-04]
#
# Best model at step 80000:
#   train loss: 5.28e-06
#   test loss: 7.97e-06
#   test metric: [7.27e-04]
#
# 'train' took 3.679586 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 80000     [4.10e-06, 6.27e-07, 5.54e-07]    [6.79e-06, 6.27e-07, 5.54e-07]    [7.27e-04]
# 81000     [5.55e-05, 3.61e-06, 1.51e-06]    [3.20e-05, 3.61e-06, 1.51e-06]    [1.74e-03]
#
# Best model at step 80000:
#   train loss: 5.28e-06
#   test loss: 7.97e-06
#   test metric: [7.27e-04]
#
# 'train' took 4.053854 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 81000     [5.55e-05, 3.61e-06, 1.51e-06]    [3.20e-05, 3.61e-06, 1.51e-06]    [1.74e-03]
# 82000     [9.49e-06, 7.24e-07, 7.06e-07]    [1.17e-05, 7.24e-07, 7.06e-07]    [8.64e-04]
#
# Best model at step 80000:
#   train loss: 5.28e-06
#   test loss: 7.97e-06
#   test metric: [7.27e-04]
#
# 'train' took 3.941346 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 82000     [9.49e-06, 7.24e-07, 7.06e-07]    [1.17e-05, 7.24e-07, 7.06e-07]    [8.64e-04]
# 83000     [3.96e-06, 6.28e-07, 5.41e-07]    [6.38e-06, 6.28e-07, 5.41e-07]    [7.23e-04]
#
# Best model at step 83000:
#   train loss: 5.13e-06
#   test loss: 7.54e-06
#   test metric: [7.23e-04]
#
# 'train' took 3.743960 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 83000     [3.96e-06, 6.28e-07, 5.41e-07]    [6.38e-06, 6.28e-07, 5.41e-07]    [7.23e-04]
# 84000     [4.13e-06, 6.08e-07, 5.53e-07]    [6.57e-06, 6.08e-07, 5.53e-07]    [7.12e-04]
#
# Best model at step 83000:
#   train loss: 5.13e-06
#   test loss: 7.54e-06
#   test metric: [7.23e-04]
#
# 'train' took 4.104925 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 84000     [4.13e-06, 6.08e-07, 5.53e-07]    [6.57e-06, 6.08e-07, 5.53e-07]    [7.12e-04]
# 85000     [3.57e-05, 2.53e-06, 1.44e-06]    [1.89e-05, 2.53e-06, 1.44e-06]    [1.39e-03]
#
# Best model at step 83000:
#   train loss: 5.13e-06
#   test loss: 7.54e-06
#   test metric: [7.23e-04]
#
# 'train' took 3.936474 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 85000     [3.57e-05, 2.53e-06, 1.44e-06]    [1.89e-05, 2.53e-06, 1.44e-06]    [1.39e-03]
# 86000     [4.22e-06, 6.67e-07, 4.76e-07]    [6.76e-06, 6.67e-07, 4.76e-07]    [7.77e-04]
#
# Best model at step 83000:
#   train loss: 5.13e-06
#   test loss: 7.54e-06
#   test metric: [7.23e-04]
#
# 'train' took 3.786989 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 86000     [4.22e-06, 6.67e-07, 4.76e-07]    [6.76e-06, 6.67e-07, 4.76e-07]    [7.77e-04]
# 87000     [9.50e-06, 9.38e-07, 4.61e-07]    [1.02e-05, 9.38e-07, 4.61e-07]    [9.78e-04]
#
# Best model at step 83000:
#   train loss: 5.13e-06
#   test loss: 7.54e-06
#   test metric: [7.23e-04]
#
# 'train' took 4.084965 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 87000     [9.50e-06, 9.38e-07, 4.61e-07]    [1.02e-05, 9.38e-07, 4.61e-07]    [9.78e-04]
# 88000     [3.84e-06, 6.13e-07, 5.38e-07]    [6.01e-06, 6.13e-07, 5.38e-07]    [7.13e-04]
#
# Best model at step 88000:
#   train loss: 4.99e-06
#   test loss: 7.16e-06
#   test metric: [7.13e-04]
#
# 'train' took 4.040559 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 88000     [3.84e-06, 6.13e-07, 5.38e-07]    [6.01e-06, 6.13e-07, 5.38e-07]    [7.13e-04]
# 89000     [3.72e-06, 6.19e-07, 4.98e-07]    [6.15e-06, 6.19e-07, 4.98e-07]    [7.36e-04]
#
# Best model at step 89000:
#   train loss: 4.83e-06
#   test loss: 7.27e-06
#   test metric: [7.36e-04]
#
# 'train' took 3.833306 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 89000     [3.72e-06, 6.19e-07, 4.98e-07]    [6.15e-06, 6.19e-07, 4.98e-07]    [7.36e-04]
# 90000     [3.67e-06, 6.11e-07, 5.11e-07]    [5.95e-06, 6.11e-07, 5.11e-07]    [7.22e-04]
#
# Best model at step 90000:
#   train loss: 4.80e-06
#   test loss: 7.08e-06
#   test metric: [7.22e-04]
#
# 'train' took 4.186991 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 90000     [3.67e-06, 6.11e-07, 5.11e-07]    [5.95e-06, 6.11e-07, 5.11e-07]    [7.22e-04]
# 91000     [4.07e-06, 5.99e-07, 5.55e-07]    [6.10e-06, 5.99e-07, 5.54e-07]    [7.10e-04]
#
# Best model at step 90000:
#   train loss: 4.80e-06
#   test loss: 7.08e-06
#   test metric: [7.22e-04]
#
# 'train' took 4.088818 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 91000     [4.07e-06, 5.99e-07, 5.55e-07]    [6.10e-06, 5.99e-07, 5.54e-07]    [7.10e-04]
# 92000     [8.21e-06, 8.57e-07, 7.07e-07]    [6.91e-06, 8.57e-07, 7.07e-07]    [8.00e-04]
#
# Best model at step 90000:
#   train loss: 4.80e-06
#   test loss: 7.08e-06
#   test metric: [7.22e-04]
#
# 'train' took 3.886310 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 92000     [8.21e-06, 8.57e-07, 7.07e-07]    [6.91e-06, 8.57e-07, 7.07e-07]    [8.00e-04]
# 93000     [4.35e-06, 6.32e-07, 5.70e-07]    [5.83e-06, 6.32e-07, 5.70e-07]    [7.12e-04]
#
# Best model at step 90000:
#   train loss: 4.80e-06
#   test loss: 7.08e-06
#   test metric: [7.22e-04]
#
# 'train' took 4.315102 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 93000     [4.35e-06, 6.32e-07, 5.70e-07]    [5.83e-06, 6.32e-07, 5.70e-07]    [7.12e-04]
# 94000     [3.56e-06, 6.04e-07, 4.95e-07]    [5.82e-06, 6.04e-07, 4.95e-07]    [7.26e-04]
#
# Best model at step 94000:
#   train loss: 4.66e-06
#   test loss: 6.92e-06
#   test metric: [7.26e-04]
#
# 'train' took 3.930233 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 94000     [3.56e-06, 6.04e-07, 4.95e-07]    [5.82e-06, 6.04e-07, 4.95e-07]    [7.26e-04]
# 95000     [4.11e-06, 6.75e-07, 4.33e-07]    [6.07e-06, 6.75e-07, 4.33e-07]    [7.86e-04]
#
# Best model at step 94000:
#   train loss: 4.66e-06
#   test loss: 6.92e-06
#   test metric: [7.26e-04]
#
# 'train' took 3.878338 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 95000     [4.11e-06, 6.75e-07, 4.33e-07]    [6.07e-06, 6.75e-07, 4.33e-07]    [7.86e-04]
# 96000     [1.47e-05, 1.16e-06, 9.80e-07]    [9.53e-06, 1.16e-06, 9.80e-07]    [9.39e-04]
#
# Best model at step 94000:
#   train loss: 4.66e-06
#   test loss: 6.92e-06
#   test metric: [7.26e-04]
#
# 'train' took 4.408895 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 96000     [1.47e-05, 1.16e-06, 9.80e-07]    [9.53e-06, 1.16e-06, 9.80e-07]    [9.39e-04]
# 97000     [4.38e-06, 6.34e-07, 5.70e-07]    [5.48e-06, 6.34e-07, 5.70e-07]    [7.15e-04]
#
# Best model at step 94000:
#   train loss: 4.66e-06
#   test loss: 6.92e-06
#   test metric: [7.26e-04]
#
# 'train' took 3.944634 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 97000     [4.38e-06, 6.34e-07, 5.70e-07]    [5.48e-06, 6.34e-07, 5.70e-07]    [7.15e-04]
# 98000     [1.64e-05, 1.41e-06, 3.91e-07]    [1.38e-05, 1.41e-06, 3.91e-07]    [1.22e-03]
#
# Best model at step 94000:
#   train loss: 4.66e-06
#   test loss: 6.92e-06
#   test metric: [7.26e-04]
#
# 'train' took 3.903385 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 98000     [1.64e-05, 1.41e-06, 3.91e-07]    [1.38e-05, 1.41e-06, 3.91e-07]    [1.22e-03]
# 99000     [3.39e-06, 6.13e-07, 4.60e-07]    [5.54e-06, 6.13e-07, 4.60e-07]    [7.42e-04]
#
# Best model at step 99000:
#   train loss: 4.46e-06
#   test loss: 6.61e-06
#   test metric: [7.42e-04]
#
# 'train' took 4.504831 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 99000     [3.39e-06, 6.13e-07, 4.60e-07]    [5.54e-06, 6.13e-07, 4.60e-07]    [7.42e-04]
# 100000    [3.49e-06, 6.34e-07, 4.30e-07]    [5.66e-06, 6.34e-07, 4.30e-07]    [7.61e-04]
#
# Best model at step 99000:
#   train loss: 4.46e-06
#   test loss: 6.61e-06
#   test metric: [7.42e-04]
#
# 'train' took 3.888251 s

# %%
# plot the mean residual in interpolation and extrapolation against the training epochs

plt.plot([*range(100)], l2_error_inter, label="Interpolation")
plt.plot([*range(100)], l2_error_extra, label="Extrapolation")

plt.legend()
plt.title("L2 Error during Training (sin activation)")
plt.xlabel("Epoch (in 1000)")
plt.ylabel("L2 Error")
plt.show()

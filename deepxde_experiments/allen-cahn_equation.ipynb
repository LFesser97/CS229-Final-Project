# %%
"""
allen-cahn_equation.ipynb

Created on Wed Apr 5 2023

@author: Lukas

This notebook contains all experiments on the Allen-Cahn Equation from this 
(https://deepxde.readthedocs.io/en/latest/demos/pinn_forward/allen.cahn.html) DeepXDE demo.
"""
# Out:
# '\nallen-cahn_equation.ipynb\n\nCreated on Wed Apr 5 2023\n\n@author: Lukas\n\nThis notebook contains all experiments on the Allen-Cahn Equation from this \n(https://deepxde.readthedocs.io/en/latest/demos/pinn_forward/allen.cahn.html) DeepXDE demo.\n'

# %% [markdown]
# In this notebook, [...]

# %%
# install DeepXDE

# %pip install deepxde
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepxde
#   Downloading DeepXDE-1.8.2-py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from deepxde) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.10.1)
# Collecting scikit-optimize>=0.9.0
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from deepxde) (1.22.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.1.1)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->deepxde) (3.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->deepxde) (23.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->deepxde) (3.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)
# Installing collected packages: pyaml, scikit-optimize, deepxde
# Successfully installed deepxde-1.8.2 pyaml-21.10.1 scikit-optimize-0.9.0

# %%
# import packages

import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt

from scipy.io import loadmat
from deepxde.backend import tf
# Out:
# DeepXDE backend not selected or invalid. Use tensorflow.compat.v1.
# Using backend: tensorflow.compat.v1
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Enable just-in-time compilation with XLA.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.

# %%
# set up the problem

def gen_testdata():
    data = loadmat("/content/Allen_Cahn.mat")

    t = data["t"]
    x = data["x"]
    u = data["u"]

    dt = dx = 0.01
    xx, tt = np.meshgrid(x, t)
    X = np.vstack((np.ravel(xx), np.ravel(tt))).T
    y = u.flatten()[:, None]
    return X, y

geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)
d = 0.001

def pde(x, y):
    dy_t = dde.grad.jacobian(y, x, i=0, j=1)
    dy_xx = dde.grad.hessian(y, x, i=0, j=0)
    return dy_t - d * dy_xx - 5 * (y - y**3)

# define the boundary and initial conditions

def func(x):
    return (x[:, 0:1])**2 * np.cos(np.pi * x[:, 0:1])

bc = dde.icbc.DirichletBC(geomtime, lambda x: -1, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(geomtime, lambda x: (x[:, 0:1])**2 * np.cos(np.pi * x[:, 0:1]), lambda _, on_initial: on_initial)

# Hard restraints on initial + boundary conditions   MIGHT WANT TO TEST THE EFFECT OF THIS ON EXTRAPOLATION BEHVAVIOR
def output_transform(x, y):
   return x[:, 0:1]**2 * tf.cos(np.pi * x[:, 0:1]) + x[:, 1:2] * (1 - x[:, 0:1]**2) * y

data = dde.data.TimePDE(geomtime, pde, [bc, ic], num_domain=8000, num_boundary=400, num_initial=800)

# %%
# set up the model

net = dde.nn.FNN([2] + [50] * 3 + [1], "tanh", "Glorot normal")
# net.apply_output_transform(output_transform)
model = dde.Model(data, net)

model.compile("adam", lr=1e-3)
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.103380 s
#
# 'compile' took 1.161540 s

# %%
# train the model

losshistory, train_state  = model.train(epochs=30000)
# Out:
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Initializing variables...
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.52e+00, 1.37e+00, 2.15e-01]    [1.52e+00, 1.37e+00, 2.15e-01]    []
# 1000      [2.29e-02, 2.18e-02, 5.49e-02]    [2.29e-02, 2.18e-02, 5.49e-02]    []
# 2000      [6.90e-03, 2.11e-03, 9.03e-03]    [6.90e-03, 2.11e-03, 9.03e-03]    []
# 3000      [1.33e-03, 4.03e-04, 2.20e-03]    [1.33e-03, 4.03e-04, 2.20e-03]    []
# 4000      [5.24e-04, 2.31e-04, 1.79e-03]    [5.24e-04, 2.31e-04, 1.79e-03]    []
# 5000      [2.99e-04, 2.43e-04, 1.54e-03]    [2.99e-04, 2.43e-04, 1.54e-03]    []
# 6000      [2.42e-04, 2.37e-04, 1.47e-03]    [2.42e-04, 2.37e-04, 1.47e-03]    []
# 7000      [3.35e-04, 2.66e-04, 1.33e-03]    [3.35e-04, 2.66e-04, 1.33e-03]    []
# 8000      [1.97e-04, 2.41e-04, 1.31e-03]    [1.97e-04, 2.41e-04, 1.31e-03]    []
# 9000      [3.20e-04, 2.16e-04, 1.32e-03]    [3.20e-04, 2.16e-04, 1.32e-03]    []
# 10000     [1.68e-04, 2.49e-04, 1.18e-03]    [1.68e-04, 2.49e-04, 1.18e-03]    []
# 11000     [1.56e-04, 2.53e-04, 1.11e-03]    [1.56e-04, 2.53e-04, 1.11e-03]    []
# 12000     [1.51e-04, 2.53e-04, 1.03e-03]    [1.51e-04, 2.53e-04, 1.03e-03]    []
# 13000     [1.37e-04, 2.40e-04, 9.65e-04]    [1.37e-04, 2.40e-04, 9.65e-04]    []
# 14000     [1.55e-04, 2.30e-04, 8.93e-04]    [1.55e-04, 2.30e-04, 8.93e-04]    []
# 15000     [1.44e-04, 2.16e-04, 8.36e-04]    [1.44e-04, 2.16e-04, 8.36e-04]    []
# 16000     [1.52e-04, 1.96e-04, 7.96e-04]    [1.52e-04, 1.96e-04, 7.96e-04]    []
# 17000     [1.60e-04, 1.85e-04, 7.44e-04]    [1.60e-04, 1.85e-04, 7.44e-04]    []
# 18000     [1.63e-04, 1.66e-04, 7.11e-04]    [1.63e-04, 1.66e-04, 7.11e-04]    []
# 19000     [2.13e-04, 1.66e-04, 6.48e-04]    [2.13e-04, 1.66e-04, 6.48e-04]    []
# 20000     [1.70e-04, 1.37e-04, 6.43e-04]    [1.70e-04, 1.37e-04, 6.43e-04]    []
# 21000     [1.72e-04, 1.31e-04, 6.16e-04]    [1.72e-04, 1.31e-04, 6.16e-04]    []
# 22000     [1.70e-04, 1.23e-04, 5.99e-04]    [1.70e-04, 1.23e-04, 5.99e-04]    []
# 23000     [1.83e-04, 1.14e-04, 5.90e-04]    [1.83e-04, 1.14e-04, 5.90e-04]    []
# 24000     [1.70e-04, 1.19e-04, 5.50e-04]    [1.70e-04, 1.19e-04, 5.50e-04]    []
# 25000     [1.67e-04, 1.14e-04, 5.35e-04]    [1.67e-04, 1.14e-04, 5.35e-04]    []
# 26000     [2.04e-04, 1.24e-04, 5.02e-04]    [2.04e-04, 1.24e-04, 5.02e-04]    []
# 27000     [9.75e-04, 1.95e-04, 4.64e-04]    [9.75e-04, 1.95e-04, 4.64e-04]    []
# 28000     [1.69e-04, 1.07e-04, 4.84e-04]    [1.69e-04, 1.07e-04, 4.84e-04]    []
# 29000     [1.67e-04, 1.10e-04, 4.64e-04]    [1.67e-04, 1.10e-04, 4.64e-04]    []
# 30000     [2.65e-04, 1.33e-04, 4.24e-04]    [2.65e-04, 1.33e-04, 4.24e-04]    []
#
# Best model at step 29000:
#   train loss: 7.41e-04
#   test loss: 7.41e-04
#   test metric: []
#
# 'train' took 59.195081 s

# %%
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...

# %%
X, y_true = gen_testdata()
y_pred = model.predict(X)
f = model.predict(X, operator=pde)
print("Mean residual:", np.mean(np.absolute(f)))
print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))
# Out:
# Mean residual: 0.2703169
# L2 relative error: 0.3903796917415757

# %%
# compute the L2 relative error between the true solution and the predicted solution

rel_l2_errors = []

for i in range(0, 20200, 201):
    y_pred = model.predict(X[i:i+201])
    y_sol = y_true[i:i+201]

    # collect the relative L2 errors in a list
    rel_l2_errors.append(dde.metrics.l2_relative_error(y_sol, y_pred))


# plot the relative L2 errors

x = np.linspace(0, 1, 101)
plt.plot(x, rel_l2_errors)
plt.xlabel("t")
plt.ylabel("L2 relative error")
plt.show()

# %%
# compute the absolute residuals

absolute_residual = []

for i in range(0, 20200, 201):
    absolute_residual.append(np.mean(np.absolute(f)[i:i+201]))


# plot the relative absolute residuals

x = np.linspace(0, 1, 101)
plt.plot(x, absolute_residual)
plt.xlabel("t")
plt.ylabel("Absolute Residual")
plt.show()

# %%
zero_predictions = [] # actually evaluations of the model at t = 0.1 ...
half_predictions = []
one_predictions = []

# %%
for i in range(5):
    model.train(iterations=6000)

    x = geom.uniform_points(201, True)
    t = np.full(201, 0.1)
    x = np.hstack((x, t.reshape(-1, 1)))
    y = model.predict(x)
    zero_predictions.append(y)

    x = geom.uniform_points(201, True)
    t = np.full(201, 0.5)
    x = np.hstack((x, t.reshape(-1, 1)))
    y = model.predict(x)
    half_predictions.append(y)

    x = geom.uniform_points(201, True)
    t = np.full(201, 1.0)
    x = np.hstack((x, t.reshape(-1, 1)))
    y = model.predict(x)
    one_predictions.append(y)
# Out:
# Initializing variables...
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [6.40e-01, 1.16e+00, 1.68e-01]    [6.40e-01, 1.16e+00, 1.68e-01]    []
# 1000      [2.66e-02, 1.12e-02, 5.07e-02]    [2.66e-02, 1.12e-02, 5.07e-02]    []
# 2000      [2.11e-02, 9.25e-03, 4.03e-02]    [2.11e-02, 9.25e-03, 4.03e-02]    []
# 3000      [7.00e-03, 7.62e-04, 8.58e-03]    [7.00e-03, 7.62e-04, 8.58e-03]    []
# 4000      [1.82e-03, 1.17e-04, 3.06e-03]    [1.82e-03, 1.17e-04, 3.06e-03]    []
# 5000      [3.46e-03, 5.72e-05, 2.33e-03]    [3.46e-03, 5.72e-05, 2.33e-03]    []
# 6000      [1.56e-03, 6.93e-05, 1.70e-03]    [1.56e-03, 6.93e-05, 1.70e-03]    []
#
# Best model at step 6000:
#   train loss: 3.33e-03
#   test loss: 3.33e-03
#   test metric: []
#
# 'train' took 20.246864 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 6000      [1.56e-03, 6.93e-05, 1.70e-03]    [1.56e-03, 6.93e-05, 1.70e-03]    []
# 7000      [3.26e-04, 9.89e-05, 1.48e-03]    [3.26e-04, 9.89e-05, 1.48e-03]    []
# 8000      [3.37e-04, 1.14e-04, 1.36e-03]    [3.37e-04, 1.14e-04, 1.36e-03]    []
# 9000      [4.54e-04, 1.17e-04, 1.29e-03]    [4.54e-04, 1.17e-04, 1.29e-03]    []
# 10000     [3.08e-04, 1.11e-04, 1.27e-03]    [3.08e-04, 1.11e-04, 1.27e-03]    []
# 11000     [1.97e-04, 9.71e-05, 1.28e-03]    [1.97e-04, 9.71e-05, 1.28e-03]    []
# 12000     [1.78e-04, 9.60e-05, 1.25e-03]    [1.78e-04, 9.60e-05, 1.25e-03]    []
#
# Best model at step 12000:
#   train loss: 1.52e-03
#   test loss: 1.52e-03
#   test metric: []
#
# 'train' took 17.853040 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 12000     [1.78e-04, 9.60e-05, 1.25e-03]    [1.78e-04, 9.60e-05, 1.25e-03]    []
# 13000     [1.91e-04, 1.04e-04, 1.19e-03]    [1.91e-04, 1.04e-04, 1.19e-03]    []
# 14000     [1.62e-04, 9.75e-05, 1.17e-03]    [1.62e-04, 9.75e-05, 1.17e-03]    []
# 15000     [1.62e-04, 9.94e-05, 1.13e-03]    [1.62e-04, 9.94e-05, 1.13e-03]    []
# 16000     [2.35e-04, 1.05e-04, 1.08e-03]    [2.35e-04, 1.05e-04, 1.08e-03]    []
# 17000     [4.65e-03, 1.24e-04, 1.33e-03]    [4.65e-03, 1.24e-04, 1.33e-03]    []
# 18000     [9.58e-04, 1.31e-04, 1.02e-03]    [9.58e-04, 1.31e-04, 1.02e-03]    []
#
# Best model at step 15000:
#   train loss: 1.39e-03
#   test loss: 1.39e-03
#   test metric: []
#
# 'train' took 17.700040 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 18000     [9.58e-04, 1.31e-04, 1.02e-03]    [9.58e-04, 1.31e-04, 1.02e-03]    []
# 19000     [8.54e-04, 9.20e-05, 1.00e-03]    [8.54e-04, 9.20e-05, 1.00e-03]    []
# 20000     [4.96e-04, 9.87e-05, 8.90e-04]    [4.96e-04, 9.87e-05, 8.90e-04]    []
# 21000     [1.61e-04, 7.04e-05, 9.19e-04]    [1.61e-04, 7.04e-05, 9.19e-04]    []
# 22000     [6.50e-04, 9.65e-05, 8.21e-04]    [6.50e-04, 9.65e-05, 8.21e-04]    []
# 23000     [1.51e-04, 5.74e-05, 8.61e-04]    [1.51e-04, 5.74e-05, 8.61e-04]    []
# 24000     [2.84e-04, 6.35e-05, 7.95e-04]    [2.84e-04, 6.35e-05, 7.95e-04]    []
#
# Best model at step 23000:
#   train loss: 1.07e-03
#   test loss: 1.07e-03
#   test metric: []
#
# 'train' took 17.791460 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 24000     [2.84e-04, 6.35e-05, 7.95e-04]    [2.84e-04, 6.35e-05, 7.95e-04]    []
# 25000     [1.48e-04, 4.66e-05, 7.94e-04]    [1.48e-04, 4.66e-05, 7.94e-04]    []
# 26000     [1.40e-04, 4.10e-05, 7.74e-04]    [1.40e-04, 4.10e-05, 7.74e-04]    []
# 27000     [2.41e-04, 3.92e-05, 7.21e-04]    [2.41e-04, 3.92e-05, 7.21e-04]    []
# 28000     [1.33e-04, 3.19e-05, 7.28e-04]    [1.33e-04, 3.19e-05, 7.28e-04]    []
# 29000     [1.33e-04, 2.67e-05, 7.23e-04]    [1.33e-04, 2.67e-05, 7.23e-04]    []
# 30000     [1.06e-03, 6.67e-05, 5.98e-04]    [1.06e-03, 6.67e-05, 5.98e-04]    []
#
# Best model at step 29000:
#   train loss: 8.83e-04
#   test loss: 8.83e-04
#   test metric: []
#
# 'train' took 17.711918 s

# %%
# plot the solution and compare it to the true solution

for i in range(len(zero_predictions)):
    plt.plot(np.linspace(-1, 1, 201), zero_predictions[i][:, 0], label="PINN, " + str((i+1) * 6000))

plt.plot(np.linspace(-1, 1, 201), y_true[2010:2211], label="True Solution")
plt.legend()
plt.title("Functions learned at t = 0.1")
plt.xlabel("x")
plt.ylabel("u(x, 0)")
plt.show()

# %%
# plot the solution and compare it to the true solution

for i in range(len(zero_predictions)):
    plt.plot(np.linspace(-1, 1, 201), half_predictions[i][:, 0], label="PINN, " + str((i+1) * 6000))

plt.plot(np.linspace(-1, 1, 201), y_true[10050:10251], label="True Solution")
plt.legend()
plt.title("Functions learned at t = 0.5")
plt.xlabel("x")
plt.ylabel("u(x, 0.5)")
plt.show()

# %%
# plot the solution and compare it to the true solution

for i in range(len(zero_predictions)):
    plt.plot(np.linspace(-1, 1, 201), one_predictions[i][:, 0], label="PINN, " + str((i+1) * 6000))

plt.plot(np.linspace(-1, 1, 201), y_true[20100:20301], label="True Solution")
plt.legend()
plt.title("Functions learned at t = 1")
plt.xlabel("x")
plt.ylabel("u(x, 1)")
plt.show()

# %%
mean_residual_inter = []
mean_residual_extra = []

l2_error_inter = []
l2_error_extra = []

# %%
# record mean residuals and l2-residuals over training epochs for t in [0, 1]

for i in range(30):
    model.train(iterations=1000)

    y_pred = model.predict(X)
    f = model.predict(X, operator=pde)

    mean_residual_inter.append(np.mean(np.absolute(f)[:10050]))
    l2_error_inter.append(dde.metrics.l2_relative_error(y_true[:10050], y_pred[:10050]))

    mean_residual_extra.append(np.mean(np.absolute(f)[10050:]))
    l2_error_extra.append(dde.metrics.l2_relative_error(y_true[10050:], y_pred[10050:]))
# Out:
# Initializing variables...
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 0         [7.37e-01]    [7.37e-01]    []
# 1000      [9.23e-03]    [9.23e-03]    []
#
# Best model at step 1000:
#   train loss: 9.23e-03
#   test loss: 9.23e-03
#   test metric: []
#
# 'train' took 14.863271 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 1000      [9.23e-03]    [9.23e-03]    []
# 2000      [3.45e-03]    [3.45e-03]    []
#
# Best model at step 2000:
#   train loss: 3.45e-03
#   test loss: 3.45e-03
#   test metric: []
#
# 'train' took 8.081609 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 2000      [3.45e-03]    [3.45e-03]    []
# 3000      [1.20e-03]    [1.20e-03]    []
#
# Best model at step 3000:
#   train loss: 1.20e-03
#   test loss: 1.20e-03
#   test metric: []
#
# 'train' took 8.201658 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 3000      [1.20e-03]    [1.20e-03]    []
# 4000      [6.14e-04]    [6.14e-04]    []
#
# Best model at step 4000:
#   train loss: 6.14e-04
#   test loss: 6.14e-04
#   test metric: []
#
# 'train' took 8.123132 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 4000      [6.14e-04]    [6.14e-04]    []
# 5000      [3.45e-04]    [3.45e-04]    []
#
# Best model at step 5000:
#   train loss: 3.45e-04
#   test loss: 3.45e-04
#   test metric: []
#
# 'train' took 8.102534 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 5000      [3.45e-04]    [3.45e-04]    []
# 6000      [2.29e-04]    [2.29e-04]    []
#
# Best model at step 6000:
#   train loss: 2.29e-04
#   test loss: 2.29e-04
#   test metric: []
#
# 'train' took 8.248153 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 6000      [2.29e-04]    [2.29e-04]    []
# 7000      [1.37e-04]    [1.37e-04]    []
#
# Best model at step 7000:
#   train loss: 1.37e-04
#   test loss: 1.37e-04
#   test metric: []
#
# 'train' took 8.227731 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 7000      [1.37e-04]    [1.37e-04]    []
# 8000      [8.73e-05]    [8.73e-05]    []
#
# Best model at step 8000:
#   train loss: 8.73e-05
#   test loss: 8.73e-05
#   test metric: []
#
# 'train' took 8.475919 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 8000      [8.73e-05]    [8.73e-05]    []
# 9000      [6.08e-05]    [6.08e-05]    []
#
# Best model at step 9000:
#   train loss: 6.08e-05
#   test loss: 6.08e-05
#   test metric: []
#
# 'train' took 8.645428 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 9000      [6.08e-05]    [6.08e-05]    []
# 10000     [5.48e-05]    [5.48e-05]    []
#
# Best model at step 10000:
#   train loss: 5.48e-05
#   test loss: 5.48e-05
#   test metric: []
#
# 'train' took 8.715587 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 10000     [5.48e-05]    [5.48e-05]    []
# 11000     [4.06e-05]    [4.06e-05]    []
#
# Best model at step 11000:
#   train loss: 4.06e-05
#   test loss: 4.06e-05
#   test metric: []
#
# 'train' took 8.540174 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 11000     [4.06e-05]    [4.06e-05]    []
# 12000     [4.85e-05]    [4.85e-05]    []
#
# Best model at step 11000:
#   train loss: 4.06e-05
#   test loss: 4.06e-05
#   test metric: []
#
# 'train' took 8.589124 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 12000     [4.85e-05]    [4.85e-05]    []
# 13000     [3.36e-05]    [3.36e-05]    []
#
# Best model at step 13000:
#   train loss: 3.36e-05
#   test loss: 3.36e-05
#   test metric: []
#
# 'train' took 8.804535 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 13000     [3.36e-05]    [3.36e-05]    []
# 14000     [3.10e-05]    [3.10e-05]    []
#
# Best model at step 14000:
#   train loss: 3.10e-05
#   test loss: 3.10e-05
#   test metric: []
#
# 'train' took 9.026458 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 14000     [3.10e-05]    [3.10e-05]    []
# 15000     [6.30e-05]    [6.30e-05]    []
#
# Best model at step 14000:
#   train loss: 3.10e-05
#   test loss: 3.10e-05
#   test metric: []
#
# 'train' took 9.192565 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 15000     [6.30e-05]    [6.30e-05]    []
# 16000     [2.72e-05]    [2.72e-05]    []
#
# Best model at step 16000:
#   train loss: 2.72e-05
#   test loss: 2.72e-05
#   test metric: []
#
# 'train' took 9.986521 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 16000     [2.72e-05]    [2.72e-05]    []
# 17000     [2.43e-05]    [2.43e-05]    []
#
# Best model at step 17000:
#   train loss: 2.43e-05
#   test loss: 2.43e-05
#   test metric: []
#
# 'train' took 9.513784 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 17000     [2.43e-05]    [2.43e-05]    []
# 18000     [2.31e-05]    [2.31e-05]    []
#
# Best model at step 18000:
#   train loss: 2.31e-05
#   test loss: 2.31e-05
#   test metric: []
#
# 'train' took 9.448237 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 18000     [2.31e-05]    [2.31e-05]    []
# 19000     [3.09e-05]    [3.09e-05]    []
#
# Best model at step 18000:
#   train loss: 2.31e-05
#   test loss: 2.31e-05
#   test metric: []
#
# 'train' took 9.426499 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 19000     [3.09e-05]    [3.09e-05]    []
# 20000     [1.91e-05]    [1.91e-05]    []
#
# Best model at step 20000:
#   train loss: 1.91e-05
#   test loss: 1.91e-05
#   test metric: []
#
# 'train' took 9.301422 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 20000     [1.91e-05]    [1.91e-05]    []
# 21000     [1.78e-05]    [1.78e-05]    []
#
# Best model at step 21000:
#   train loss: 1.78e-05
#   test loss: 1.78e-05
#   test metric: []
#
# 'train' took 8.784860 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 21000     [1.78e-05]    [1.78e-05]    []
# 22000     [1.48e-04]    [1.48e-04]    []
#
# Best model at step 21000:
#   train loss: 1.78e-05
#   test loss: 1.78e-05
#   test metric: []
#
# 'train' took 9.078933 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 22000     [1.48e-04]    [1.48e-04]    []
# 23000     [1.54e-05]    [1.54e-05]    []
#
# Best model at step 23000:
#   train loss: 1.54e-05
#   test loss: 1.54e-05
#   test metric: []
#
# 'train' took 9.194888 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 23000     [1.54e-05]    [1.54e-05]    []
# 24000     [1.46e-05]    [1.46e-05]    []
#
# Best model at step 24000:
#   train loss: 1.46e-05
#   test loss: 1.46e-05
#   test metric: []
#
# 'train' took 9.610399 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 24000     [1.46e-05]    [1.46e-05]    []
# 25000     [1.41e-05]    [1.41e-05]    []
#
# Best model at step 25000:
#   train loss: 1.41e-05
#   test loss: 1.41e-05
#   test metric: []
#
# 'train' took 9.737255 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 25000     [1.41e-05]    [1.41e-05]    []
# 26000     [1.33e-05]    [1.33e-05]    []
#
# Best model at step 26000:
#   train loss: 1.33e-05
#   test loss: 1.33e-05
#   test metric: []
#
# 'train' took 15.938733 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 26000     [1.33e-05]    [1.33e-05]    []
# 27000     [1.30e-05]    [1.30e-05]    []
#
# Best model at step 27000:
#   train loss: 1.30e-05
#   test loss: 1.30e-05
#   test metric: []
#
# 'train' took 12.312879 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 27000     [1.30e-05]    [1.30e-05]    []
# 28000     [3.81e-05]    [3.81e-05]    []
#
# Best model at step 27000:
#   train loss: 1.30e-05
#   test loss: 1.30e-05
#   test metric: []
#
# 'train' took 12.542195 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 28000     [3.81e-05]    [3.81e-05]    []
# 29000     [2.25e-05]    [2.25e-05]    []
#
# Best model at step 27000:
#   train loss: 1.30e-05
#   test loss: 1.30e-05
#   test metric: []
#
# 'train' took 12.453858 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 29000     [2.25e-05]    [2.25e-05]    []
# 30000     [1.15e-05]    [1.15e-05]    []
#
# Best model at step 30000:
#   train loss: 1.15e-05
#   test loss: 1.15e-05
#   test metric: []
#
# 'train' took 12.122914 s

# %%
# plot the mean residual in interpolation and extrapolation against the training epochs

plt.plot([*range(30)], mean_residual_inter, label="Interpolation")
plt.plot([*range(30)], mean_residual_extra, label="Extrapolation")

plt.legend()
plt.title("Mean Residual Error during Training (tanh activation)")
plt.xlabel("Epoch (in 1000)")
plt.ylabel("Mean Residual")
plt.show()

# %%
# plot the mean residual in interpolation and extrapolation against the training epochs

plt.plot([*range(30)], l2_error_inter, label="Interpolation")
plt.plot([*range(30)], l2_error_extra, label="Extrapolation")

plt.legend()
plt.title("L2 Error during Training (tanh activation)")
plt.xlabel("Epoch (in 1000)")
plt.ylabel("L2 Error")
plt.show()
